# %% [markdown]
# <a href="https://colab.research.google.com/github/venezianof/booksum/blob/main/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 1042, done.
# remote: Counting objects: 100% (1042/1042), done.
# remote: Compressing objects: 100% (866/866), done.
# remote: Total 1042 (delta 177), reused 673 (delta 156), pack-reused 0 (from 0)
# Receiving objects: 100% (1042/1042), 31.17 MiB | 17.12 MiB/s, done.
# Resolving deltas: 100% (177/177), done.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#                  upgrading npm...
#   node           v20.19.0 | npm 11.12.1
#                  installing bun...
#                  bun installed (1.3.11)
#                  building frontend...
#    Using bun for package install (faster)
#   frontend       built
#                  Colab detected, installing Studio backend dependencies...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.5/69.5 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.4/340.4 kB 30.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 116.3 MB/s eta 0:00:00
# ✅ Studio backend dependencies installed into system Python
#   deps           [====================] 11/11  finalizing
#   deps           installed
#   transformers   5.x pre-installed
#                  resolved llama.cpp tag: b8508
#                  installing prebuilt llama.cpp...
# [llama-prebuilt] no existing llama.cpp install detected at /root/.unsloth/llama.cpp; performing fresh prebuilt install
# [llama-prebuilt] published_release: repo=unslothai/llama.cpp
# [llama-prebuilt] published_release: tag=b8508
# [llama-prebuilt] published_release: manifest=llama-prebuilt-manifest.json
# [llama-prebuilt] published_release: upstream_tag=b8508
# [llama-prebuilt] torch_cuda_preference: selected runtime_line=cuda12 from torch.version.cuda=12.8
# [llama-prebuilt] linux_cuda_selection: release=b8508
# [llama-prebuilt] linux_cuda_selection: detected_sms=75
# [llama-prebuilt] linux_cuda_selection: detected_runtime_lines=cuda12
# [llama-prebuilt] linux_cuda_selection: driver_runtime_lines=cuda13,cuda12
# [llama-prebuilt] linux_cuda_selection: compatible_runtime_lines=cuda12
# [llama-prebuilt] linux_cuda_selection: runtime_dirs cuda13=none
# [llama-prebuilt] linux_cuda_selection: runtime_dirs cuda12=/usr/local/cuda-12.8/targets/x86_64-linux/lib,/usr/local/lib/python3.12/dist-packages/nvidia/cuda_runtime/lib,/usr/local/lib/python3.12/dist-packages/nvidia/cublas/lib
# [llama-prebuilt] linux_cuda_selection: published_assets=app-b8508-linux-x64-cuda12-newer.tar.gz,app-b8508-linux-x64-cuda12-older.tar.gz,app-b8508-linux-x64-cuda12-portable.tar.gz,app-b8508-linux-x64-cuda13-newer.tar.gz,app-b8508-linux-x64-cuda13-older.tar.gz,app-b8508-linux-x64-cuda13-portable.tar.gz
# [llama-prebuilt] linux_cuda_selection: torch_preferred_runtime_line=cuda12 reordered_attempts=cuda12
# [llama-prebuilt] linux_cuda_selection: accept app-b8508-linux-x64-cuda12-older.tar.gz runtime_line=cuda12 coverage_class=older coverage=70-89 supported=70,75,80,86,89
# [llama-prebuilt] linux_cuda_selection: reject app-b8508-linux-x64-cuda12-newer.tar.gz runtime_line=cuda12 coverage_class=newer coverage=86-120 supported=86,89,90,100,120 reasons=missing_sms=75 out_of_range_sms=75
# [llama-prebuilt] linux_cuda_selection: accept app-b8508-linux-x64-cuda12-portable.tar.gz runtime_line=cuda12 coverage_class=portable coverage=70-120 supported=70,75,80,86,89,90,100,120
# [llama-prebuilt] linux_cuda_selection: attempt_order=app-b8508-linux-x64-cuda12-older.tar.gz,app-b8508-linux-x64-cuda12-portable.tar.gz
# [llama-prebuilt] selected app-b8508-linux-x64-cuda12-older.tar.gz (published) for Linux x86_64
# [llama-prebuilt] downloading tiny GGUF validation model
# [llama-prebuilt] created install staging dir /root/.unsloth/.staging/llama.cpp.staging-8rtfrkpj
# [llama-prebuilt] hydrating upstream llama.cpp source for b8508 into /root/.unsloth/.staging/llama.cpp.staging-8rtfrkpj
# [llama-prebuilt] downloading llama.cpp source tree for upstream tag b8508
# [llama-prebuilt] verified llama.cpp source tree for b8508 sha256=a41d2c532c44ff6fc79da2a3d306d6e4f654e32e88fe886e496a55c338774f9f
# [llama-prebuilt] overlaying prebuilt bundle app-b8508-linux-x64-cuda12-older.tar.gz into /root/.unsloth/.staging/llama.cpp.staging-8rtfrkpj
# [llama-prebuilt] downloading app-b8508-linux-x64-cuda12-older.tar.gz from published release
# [llama-prebuilt] verified prebuilt archive app-b8508-linux-x64-cuda12-older.tar.gz sha256=d40fb39a6f215459fa6cddcabf6b8661617caac500cff9961fdc91120176f7cc
# [llama-prebuilt] staged prebuilt validation succeeded for app-b8508-linux-x64-cuda12-older.tar.gz
# [llama-prebuilt] activating staged install /root/.unsloth/.staging/llama.cpp.staging-8rtfrkpj -> /root/.unsloth/llama.cpp
# [llama-prebuilt] activated staged install at /root/.unsloth/llama.cpp
# [llama-prebuilt] confirming activated install tree at /root/.unsloth/llama.cpp
# [llama-prebuilt] activated install tree confirmed at /root/.unsloth/llama.cpp
#   llama.cpp      prebuilt installed and validated
#
#   ────────────────────────────────────────────────────
#   Unsloth Studio Setup Complete
#   ────────────────────────────────────────────────────
#                  from colab import start
#                  start()

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys, time
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()
# Out:
# 2026-03-28 05:05:12 [info     ] 🦥 Starting Unsloth Studio...
# 2026-03-28 05:05:12 [info     ]    Loading backend...
# 2026-03-28 05:05:12 [info     ]    Starting server...
# INFO:     Started server process [592]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8888 (Press CTRL+C to quit)
# Hardware detected: CUDA — Tesla T4
#
# ============================================================
# DEFAULT ADMIN ACCOUNT CREATED
# Sign in with the seeded credentials and change the password immediately:
#
#     username: unsloth
#     password: HydroxideUnthreadChangeObvious
#
# ============================================================
#
# {"timestamp": "2026-03-28T05:05:24.305577Z", "level": "info", "event": "Pre-caching helper GGUF: unsloth/Qwen3.5-4B-GGUF/Qwen3.5-4B-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-03-28T05:05:25.966279Z", "level": "info", "event": "   Server started!"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Unsloth Studio is Ready!
#         </h2>
#         <a href="https://8888-gpu-t4-s-kkb-ass1c0-7aozo3sk0nb5-c.asia-southeast1-0.prod.colab.dev" target="_blank"
#            style="display: inline-flex; align-items: center; gap: 10px; padding: 14px 28px;
#                   background: #000000; color: white; text-decoration: none; border-radius: 8px;
#                   font-weight: 800; font-size: 16px;">
#             <svg xmlns="http://www.w3.org/2000/svg" width="18" height="18" viewBox="0 0 24 24" fill="white"><polygon points="5,3 19,12 5,21"/></svg>
#             Open Unsloth Studio
#         </a>
#         <p style="color: #333333; margin: 16px 0 0 0; font-size: 13px; font-family: monospace;">
#             https://8888-gpu-...
#         </p>
#     </div>

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
for _ in range(10000): time.sleep(300), print("=", end = "")
# Out:
# {"timestamp": "2026-03-28T05:06:45.233079Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 1.8}
# {"timestamp": "2026-03-28T05:06:47.153772Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.53}
# {"timestamp": "2026-03-28T05:06:48.436567Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.58}
# {"timestamp": "2026-03-28T05:06:48.790562Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.42}
# {"timestamp": "2026-03-28T05:06:49.500195Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.61}
# {"timestamp": "2026-03-28T05:08:31.155401Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 78.88}
# {"timestamp": "2026-03-28T05:08:32.610845Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/change-password", "status_code": 200, "process_time_ms": 163.22}
# {"timestamp": "2026-03-28T05:08:32.981348Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.43}
# {"timestamp": "2026-03-28T05:08:33.326294Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.39}
# {"timestamp": "2026-03-28T05:08:33.671985Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.57}
# {"timestamp": "2026-03-28T05:08:34.623999Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.19}
# ={"timestamp": "2026-03-28T05:11:45.440777Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/chat", "status_code": 200, "process_time_ms": 1.69}
# {"timestamp": "2026-03-28T05:11:47.462754Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.6}
# {"timestamp": "2026-03-28T05:11:47.816634Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.38}
# {"timestamp": "2026-03-28T05:11:49.953168Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-03-28T05:11:50.467050Z", "level": "info", "event": "Top GGUF models: ['unsloth/Qwen3.5-35B-A3B-GGUF', 'unsloth/Qwen3.5-9B-GGUF', 'unsloth/Qwen3.5-27B-GGUF', 'unsloth/Qwen3.5-4B-GGUF', 'unsloth/Qwen3.5-122B-A10B-GGUF', 'unsloth/gpt-oss-20b-GGUF', 'unsloth/Qwen3-Coder-Next-GGUF', 'unsloth/Qwen3.5-0.8B-GGUF', 'unsloth/GLM-4.7-Flash-GGUF', 'unsloth/Qwen3.5-2B-GGUF', 'unsloth/LTX-2.3-GGUF', 'unsloth/Nemotron-3-Nano-30B-A3B-GGUF', 'unsloth/Qwen3.5-397B-A17B-GGUF', 'unsloth/Qwen3.5-35B-A3B-Experiments-GGUF', 'unsloth/Qwen3-VL-4B-Instruct-GGUF', 'unsloth/Qwen3-Coder-30B-A3B-Instruct-GGUF', 'unsloth/gemma-3-27b-it-GGUF', 'unsloth/gpt-oss-120b-GGUF', 'unsloth/Qwen-Image-Edit-2511-GGUF', 'unsloth/Llama-3.2-1B-Instruct-GGUF', 'unsloth/GLM-4.6V-Flash-GGUF', 'unsloth/gemma-3-12b-it-GGUF', 'unsloth/DeepSeek-R1-Distill-Qwen-1.5B-GGUF', 'unsloth/Qwen3-4B-Instruct-2507-GGUF', 'unsloth/gemma-3-270m-it-GGUF', 'unsloth/Qwen3-4B-GGUF', 'unsloth/NVIDIA-Nemotron-3-Super-120B-A12B-GGUF', 'unsloth/DeepSeek-R1-0528-Qwen3-8B-GGUF', 'unsloth/Qwen3-VL-30B-A3B-Instruct-GGUF', 'unsloth/Qwen2.5-VL-7B-Instruct-GGUF', 'unsloth/gemma-3-4b-it-GGUF', 'unsloth/MiniMax-M2.5-GGUF', 'unsloth/Qwen3-0.6B-GGUF', 'unsloth/DeepSeek-R1-Distill-Qwen-14B-GGUF', 'unsloth/Qwen3-VL-8B-Instruct-GGUF']"}
# {"timestamp": "2026-03-28T05:11:50.468091Z", "level": "info", "event": "Top hub models: ['unsloth/GLM-4.7-Flash-FP8-Dynamic', 'unsloth/mistral-7b-v0.3-bnb-4bit', 'unsloth/Meta-Llama-3.1-8B-Instruct', 'unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit', 'unsloth/DeepSeek-OCR-2', 'unsloth/Qwen3-0.6B', 'unsloth/gpt-oss-20b', 'unsloth/Llama-3.2-1B-Instruct', 'unsloth/Qwen3-0.6B-unsloth-bnb-4bit', 'unsloth/Qwen3-14B-unsloth-bnb-4bit', 'unsloth/Llama-3.1-8B-Instruct', 'unsloth/gpt-oss-20b-unsloth-bnb-4bit', 'unsloth/Llama-3.2-3B-Instruct', 'unsloth/Qwen2.5-7B-Instruct-bnb-4bit', 'unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit', 'unsloth/Qwen3.5-9B', 'unsloth/Qwen3.5-4B', 'unsloth/GLM-4.7-Flash', 'unsloth/Qwen2.5-3B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen2.5-7B', 'unsloth/Qwen3-1.7B-unsloth-bnb-4bit', 'unsloth/Qwen2-7B', 'unsloth/gpt-oss-120b-BF16', 'unsloth/Qwen3.5-2B', 'unsloth/Qwen3-4B-Base', 'unsloth/gpt-oss-20b-BF16', 'unsloth/Qwen3-8B-unsloth-bnb-4bit', 'unsloth/Llama-3.2-1B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3-4B', 'unsloth/Qwen3-8B', 'unsloth/Qwen2.5-7B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3-4B-bnb-4bit', 'unsloth/Qwen3.5-0.8B', 'unsloth/Qwen2.5-7B-Instruct', 'unsloth/Llama-3.2-3B-Instruct-unsloth-bnb-4bit', 'unsloth/llama-3-8b-bnb-4bit', 'unsloth/Qwen3-4B-unsloth-bnb-4bit', 'unsloth/DeepSeek-V3-0324-BF16', 'unsloth/Qwen3-VL-4B-Instruct-unsloth-bnb-4bit', 'unsloth/embeddinggemma-300m']"}
# {"timestamp": "2026-03-28T05:11:50.474718Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 526.23}
# {"timestamp": "2026-03-28T05:11:50.479677Z", "level": "info", "event": "Found 0 trained LoRA adapters in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-28T05:11:50.480919Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-03-28T05:11:50.486508Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 9.82}
# {"timestamp": "2026-03-28T05:11:50.487246Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 9.97}
# {"timestamp": "2026-03-28T05:11:50.487970Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 10.45}
# {"timestamp": "2026-03-28T05:12:01.941737Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-models", "status_code": 200, "process_time_ms": 5.15}
# {"timestamp": "2026-03-28T05:12:01.947505Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-gguf", "status_code": 200, "process_time_ms": 8.09}
# {"timestamp": "2026-03-28T05:12:01.948616Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 6.94}
# {"timestamp": "2026-03-28T05:12:02.349190Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 1.76}
# {"timestamp": "2026-03-28T05:12:25.449330Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 335.0}
# =====

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
