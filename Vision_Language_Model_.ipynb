# %% [markdown]
# <a href="https://colab.research.google.com/github/venezianof/booksum/blob/main/Vision_Language_Model_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cell 5: Importa Oumi e configura dipendenze
# !pip install oumi[gpu] ipywidgets
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
import oumi

# Carica il modello
model = oumi.AutoModel.from_pretrained(model_name)
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2246372463.py in <cell line: 0>()
#       6
#       7 # Carica il modello
# ----> 8 model = oumi.AutoModel.from_pretrained(model_name)
#
# AttributeError: module 'oumi' has no attribute 'AutoModel'

# %%
# Cell 6: Esempio di inferenza con il modello

# Definisci un prompt per la generazione
prompt = "Tell me a short story about a magical forest."

# Genera il testo
response = model.generate(prompt)

# Stampa la risposta
print(response)

# %%
# 📦 Installazione dipendenze Oumi
# !pip install oumi[gpu]

# %%
# 📦 Installa pacchetti aggiuntivi per i widget
# !pip install ipywidgets

# %%
# 🔇 Disabilita warning dei tokenizers
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# Cell 1: Setup
# !pip install oumi[gpu] ipywidgets
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# Cell 2: Token HF
HF_TOKEN = "incolla_qui_il_tuo_token"
os.environ["HF_TOKEN"] = HF_TOKEN

# %%
# Cell 3: Verifica GPU
import torch
if not torch.cuda.is_available() or torch.cuda.mem_get_info()[1] < 24*1024**3:
    print("⚠️ GPU insufficiente! Prova con Llama-3.2-1B-Vision-Instruct")

# %%
# Cell 4: Configura modello piccolo per test
model_name = "meta-llama/Llama-3.2-1B-Vision-Instruct"  # Usa la versione 1B!
