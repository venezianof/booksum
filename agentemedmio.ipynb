# %% [markdown]
# <a href="https://colab.research.google.com/github/venezianof/booksum/blob/main/agentemedmio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://github.com/Aperivue/medsci-skills/releases/latest/download/medsci-skills-classroom-windows.zip
# Out:
# --2026-04-26 10:03:05--  https://github.com/Aperivue/medsci-skills/releases/latest/download/medsci-skills-classroom-windows.zip
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/Aperivue/medsci-skills/releases/download/v2.1.1/medsci-skills-classroom-windows.zip [following]
# --2026-04-26 10:03:05--  https://github.com/Aperivue/medsci-skills/releases/download/v2.1.1/medsci-skills-classroom-windows.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !unzip medsci-skills-classroom-windows.zip -d medsci_skills_extracted
print('Extraction complete.')
# Out:
# Archive:  medsci-skills-classroom-windows.zip
#   inflating: medsci_skills_extracted/medsci-skills-classroom-v2.1.1/README_FIRST.md
#   inflating: medsci_skills_extracted/medsci-skills-classroom-v2.1.1/installers/install-macos.command
#   inflating: medsci_skills_extracted/medsci-skills-classroom-v2.1.1/installers/install-windows.cmd
#   inflating: medsci_skills_extracted/medsci-skills-classroom-v2.1.1/installers/install-windows.ps1
#   inflating: medsci_skills_extracted/medsci-skills-classroom-v2.1.1/installers/install.py
#   inflating: medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/academic-aio/SKILL.md
#   inflating: medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/add-journal/SKILL.md
#   inflating: medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/analyze-stats/SKILL.md
#   inflating: medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/analyze-stats/references/analysis_guides/missing_data.md
# ...

# %%
# !ls -R medsci_skills_extracted
# Out:
# medsci_skills_extracted:
# medsci-skills-classroom-v2.1.1
#
# medsci_skills_extracted/medsci-skills-classroom-v2.1.1:
# installers  README_FIRST.md  skills
#
# medsci_skills_extracted/medsci-skills-classroom-v2.1.1/installers:
# install-macos.command  install.py  install-windows.cmd	install-windows.ps1
#
# medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills:
# academic-aio	  deidentify	      lit-sync	       revise
# add-journal	  design-study	      make-figures     search-lit
# analyze-stats	  fill-icmje-coi      manage-project   self-review
# author-strategy   fill-protocol       ma-scout	       sync-submission
# batch-cohort	  find-cohort-gap     meta-analysis    verify-refs
# calc-sample-size  find-journal	      orchestrate      write-paper
# check-reporting   fulltext-retrieval  peer-review      write-protocol
# clean-data	  grant-builder       present-paper
# cross-national	  humanize	      publish-skill
# define-variables  intake-project      replicate-study
#
# ...

# %%
# !find medsci_skills_extracted -name "*.py"
# Out:
# medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/fill-icmje-coi/scripts/fill_icmje_coi.py
# medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/search-lit/references/parse_pubmed.py
# medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/present-paper/scripts/inject_speaker_notes.py
# medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/author-strategy/analyze_patterns.py
# medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/author-strategy/fetch_pubmed.py
# medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/verify-refs/scripts/verify_refs.py
# medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/fill-protocol/scripts/fill_form.py
# medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/fill-protocol/scripts/doc_to_docx.py
# medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/fill-protocol/scripts/inspect_template.py
# ...

# %%
# /design-study: Review study design for leakage and bias
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/design-study/design_study.py
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/design-study/design_study.py': [Errno 2] No such file or directory

# %%
# /analyze-stats: Generate DTA statistics
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/analyze-stats/analyze_stats.py
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/analyze-stats/analyze_stats.py': [Errno 2] No such file or directory

# %%
# /make-figures: Create ROC curve + STARD flow diagram
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/make-figures/make_figures.py
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/make-figures/make_figures.py': [Errno 2] No such file or directory

# %%
# /check-reporting: Audit against STARD checklist
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/check-reporting/check_reporting.py
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/check-reporting/check_reporting.py': [Errno 2] No such file or directory

# %%
# /present-paper: Analyze paper, find supporting refs, draft speaker script
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/present-paper/present_paper.py
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/present-paper/present_paper.py': [Errno 2] No such file or directory

# %%
# /search-lit: Background literature for rationale
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/search-lit/search_lit.py
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/search-lit/search_lit.py': [Errno 2] No such file or directory

# %%
# /design-study: Validate study design, identify bias risks
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/design-study/design_study.py
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/design-study/design_study.py': [Errno 2] No such file or directory

# %%
# /calc-sample-size: Power analysis with IRB justification text
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/calc-sample-size/calc_sample_size.py
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/calc-sample-size/calc_sample_size.py': [Errno 2] No such file or directory

# %%
# /write-protocol: Generate 4 core sections + 6 skeleton sections
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/write-protocol/write_protocol.py
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/write-protocol/write_protocol.py': [Errno 2] No such file or directory

# %%
# /write-paper: Case report mode (CARE 2016, 1000-word short-form)
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/write-paper/write_paper.py --mode case-report
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/write-paper/write_paper.py': [Errno 2] No such file or directory

# %%
# /self-review: Pre-submission self-check
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/self-review/self_review.py
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/self-review/self_review.py': [Errno 2] No such file or directory

# %%
# /find-journal: Identify journals accepting case reports
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/find-journal/find_journal.py
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/find-journal/find_journal.py': [Errno 2] No such file or directory

# %%
# /find-journal: Exclude rejected journal, recommend alternatives
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/find-journal/find_journal.py --exclude-rejected
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/find-journal/find_journal.py': [Errno 2] No such file or directory

# %%
# /write-paper: Generate new cover letter (Phase 8+)
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/write-paper/write_paper.py --mode cover-letter --phase 8
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/write-paper/write_paper.py': [Errno 2] No such file or directory

# %%
# /deidentify: Remove PHI from clinical data
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/deidentify/deidentify.py
# Out:
# usage: deidentify [-h] [-v] {scan,review,apply,full} ...
# deidentify: error: the following arguments are required: command

# %%
# /clean-data: Profile dataset, flag issues, generate cleaning code
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/clean-data/clean_data.py
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/clean-data/clean_data.py': [Errno 2] No such file or directory

# %%
# /analyze-stats: Run statistics on cleaned data
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/analyze-stats/analyze_stats.py
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/analyze-stats/analyze_stats.py': [Errno 2] No such file or directory

# %%
# /make-figures: Publication-ready figures
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/make-figures/make_figures.py
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/make-figures/make_figures.py': [Errno 2] No such file or directory

# %%
# /design-study: Validate study design before writing
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/design-study/design_study.py
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/design-study/design_study.py': [Errno 2] No such file or directory

# %%
# /grant-builder: Structure significance, innovation, approach
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/grant-builder/grant_builder.py
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/grant-builder/grant_builder.py': [Errno 2] No such file or directory

# %%
# /search-lit: Find supporting literature with verified citations
# !python3 medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/search-lit/search_lit.py
# Out:
# python3: can't open file '/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/search-lit/search_lit.py': [Errno 2] No such file or directory

# %% [markdown]
# # Medical Research & Therapy Agent
# This section initializes a specialized agent focused on deep literature synthesis and therapeutic recommendation auditing.

# %%
# Updated Deep Medical Research Agent with correct piping logic
class MedicalResearchAgent:
    def __init__(self):
        self.parser_path = 'medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/search-lit/references/parse_pubmed.py'
        self.deidentifier = 'medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/deidentify/deidentify.py'

    def perform_search(self, query):
        # Step 1: Search PubMed for IDs using esearch
        # Step 2: Pipe the raw result to the parser
        print(f'Ricerca PubMed in corso per: {query}')
        # In a real scenario, we'd use eutils.ncbi.nlm.nih.gov.
        # Here we simulate the command structure required by the parser:
        # !curl -s "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term={query}&retmode=json" | python3 {self.parser_path} esearch
        print('Nota: Il parser richiede dati in ingresso via pipe (es. echo <data> | python3 parser.py mode)')

    def deidentify_data(self, path):
        print(f'Running de-identification on: {path}')
        # !python3 {self.deidentifier} full --input {path}

# Initialize the agent
research_agent = MedicalResearchAgent()
print('Agente aggiornato: Il parser ora è configurato per ricevere dati via stream.')
# Out:
# Agente aggiornato: Il parser ora è configurato per ricevere dati via stream.

# %%
# Esempio di risoluzione: passiamo un JSON fittizio al parser via pipe
dummy_data = '{"esearchresult": {"idlist": ["12345", "67890"]}}'
parser_script = research_agent.parser_path

print("Eseguo il parser fornendo dati tramite pipe per evitare il blocco:")
# !echo '{dummy_data}' | python3 {parser_script} esearch
# Out:
# Eseguo il parser fornendo dati tramite pipe per evitare il blocco:
# Total results: 0
# Returned: 2
# PMIDs: 12345,67890

# %%
# Leggo la guida per i Case Report
path_case_report = 'medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/write-paper/references/paper_types/case_report.md'
with open(path_case_report, 'r') as f:
    print(f.read())
# Out:
# # Paper Type: Case Report
#
# ## Overview
#
# - **Reporting guideline:** CARE 2016 (mandatory)
# - **Typical word count:** 1000–1500 words (short-form) or 2000–3000 words (extended with literature review)
# - **Default mode:** Short-form (1000-1500 words). Use `--extended` for longer format.
# - **Structure:** Title → Abstract → Introduction → Case Presentation → Discussion → Conclusions → Patient Perspective (optional) → Informed Consent
# - **Key requirement:** Patient consent/anonymization documented
#
# ---
#
# ## CARE 2016 Checklist Quick Reference
#
# | # | Item | Section | Description |
# |---|------|---------|-------------|
# | 1 | Title | Title | Diagnosis or main symptom AND "case report" |
# | 2 | Key words | Abstract | 2-5 keywords covering the case |
# | 3 | Abstract | Abstract | Structured: Introduction, Case Presentation, Conclusion |
# | 4 | Introduction | Introduction | Background with references, why this case is reportable |
# ...

# %%
# Esecuzione ricerca PubMed basata sulla guida Case Report
import urllib.parse
import subprocess

# Definiamo la query e codifichiamola per l'URL
raw_query = '"Heberden\'s nodules"[Title] AND "case report"[Publication Type]'
encoded_query = urllib.parse.quote(raw_query)
print(f"Ricerca in corso: {raw_query}")

# Costruiamo l'URL con la query codificata
url = f"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term={encoded_query}&retmode=json"

# Eseguiamo il comando e verifichiamo l'output
parser_path = research_agent.parser_path
print("Recupero dati da NCBI...")

# Utilizziamo curl e passiamo l'output allo script di parsing
# !curl -s "{url}" | python3 {parser_path} esearch
# Out:
# Ricerca in corso: "Heberden's nodules"[Title] AND "case report"[Publication Type]
# Recupero dati da NCBI...
# Total results: 0
# Returned: 0
# PMIDs:

# %%
# Broadening the search: Title/Abstract instead of just Title
broad_query = '"Heberden\'s nodules"[Title/Abstract] AND "case report"[Publication Type]'
encoded_broad_query = urllib.parse.quote(broad_query)
print(f"Broadening search to: {broad_query}")

url_broad = f"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term={encoded_broad_query}&retmode=json"

# Execute search and parse
# !curl -s "{url_broad}" | python3 {parser_path} esearch
# Out:
# Broadening search to: "Heberden's nodules"[Title/Abstract] AND "case report"[Publication Type]
# Total results: 0
# Returned: 0
# PMIDs:

# %%
# Further broadening: Search the term without publication type restriction
general_query = '"Heberden\'s nodules"[Title/Abstract]'
encoded_general_query = urllib.parse.quote(general_query)
print(f"Searching broadly for: {general_query}")

url_general = f"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term={encoded_general_query}&retmode=json"

# Execute search and parse
# !curl -s "{url_general}" | python3 {parser_path} esearch
# Out:
# Searching broadly for: "Heberden's nodules"[Title/Abstract]
# Total results: 0
# Returned: 0
# PMIDs:

# %%
# Search for keywords without the apostrophe to avoid indexing issues
flexible_query = 'Heberden nodules'
encoded_flexible_query = urllib.parse.quote(flexible_query)
print(f"Searching for flexible terms: {flexible_query}")

url_flexible = f"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term={encoded_flexible_query}&retmode=json"

# Execute search and parse
# !curl -s "{url_flexible}" | python3 {parser_path} esearch
# Out:
# Searching for flexible terms: Heberden nodules
# Total results: 18
# Returned: 18
# PMIDs: 29471581,17322965,14677019,12180736,11759238,10531070,10408070,9709182,8978174,8883439,7822208,1643450,2237677,5962218,5931010,15394951,18130064,18149328

# %%
# Recupero i sommari per i PMIDs trovati
pmids = '29471581,17322965,14677019,12180736,11759238,10531070,10408070,9709182,8978174,8883439,7822208,1643450,2237677,5962218,5931010,15394951,18130064,18149328'

# Costruiamo l'URL per esummary
summary_url = f"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=pubmed&id={pmids}&retmode=json"

print("Recupero i dettagli degli articoli...")
# Passiamo l'output al parser in modalità 'esummary'
# !curl -s "{summary_url}" | python3 {parser_path} esummary
# Out:
# Recupero i dettagli degli articoli...
# | # | PMID | Year | Journal | Title | Authors |
# |---|------|------|---------|-------|---------|
# | 1 | 29471581 | 2018 | Arthritis & rheumatology (Hoboken, N.J.) | Brief Report: Association of Quantitative and Topographic Assessment of... | Kumar NM, ... Demehri S |
# | 2 | 17322965 | 2007 | Clinical rheumatology | The effect of radiological hand osteoarthritis on hand function. | Ozkan B, ... Barça N |
# | 3 | 14677019 | 2003 | Clinical rheumatology | The effect of hand osteoarthritis on grip and pinch strength and hand... | Bagis S, ... Erdogan C |
# | 4 | 12180736 | 2002 | The Journal of rheumatology | A cross sectional study of the association between sex, smoking, and other... | Jones G, ... Stankovich JM |
# | 5 | 11759238 | 2001 | Zeitschrift fur Rheumatologie | [In the best English manner. On the 200th anniversary of the death of William... | Keitel W |
# ...

# %% [markdown]
# # Sezione: Presentazione del Caso (CARE Checklist 5-10)
#
# ## 5. Informazioni sul Paziente (Patient Information)
# - **Dati Demografici:** [es. Donna, 52 anni]
# - **Sintomo Principale:** [es. Comparsa di noduli dolenti alle articolazioni interfalangee distali]
# - **Anamnesi Remota:** [es. Storia familiare di osteoartrosi, nessuna patologia autoimmune nota]
#
# ## 6. Reperti Clinici (Clinical Findings)
# - **Esame Obiettivo:** [Descrivere l'aspetto dei noduli di Heberden, deformità, segni di flogosi]
# - **Valutazione Funzionale:** [Range di movimento, forza della presa]
#
# ## 7. Cronologia (Timeline)
# | Data/Periodo | Evento Clinico |
# |--------------|----------------|
# | [T0] | Insorgenza dei primi sintomi |
# | [T1] | Prima valutazione clinica |
# | [T2] | Inizio trattamento |
#
# ## 8. Valutazione Diagnostica (Diagnostic Assessment)
# - **Metodi Diagnostici:** [es. Radiografia delle mani, esami ematici per escludere AR]
# - **Risultati:** [Descrivere restringimento rima articolare, osteofiti]
# - **Sfide Diagnostiche:** [Se presenti]
#
# ## 9. Intervento Terapeutico (Therapeutic Intervention)
# - **Tipo di Intervento:** [es. Fisioterapia, FANS, tutori]
# - **Somministrazione:** [Dosaggi e durata]
#
# ## 10. Follow-up e Risultati (Follow-up and Outcomes)
# - **Risultati clinici:** [Miglioramento del dolore o della funzione]
# - **Aderenza e Tollerabilità:** [Il paziente ha seguito la terapia?]
# - **Eventi Avversi:** [Se presenti]

# %% [markdown]
# ### 📝 Compilazione: Presentazione del Caso Clinico
# Utilizza questa sezione per inserire i dati del paziente.
#
# **Suggerimento Clinico:** Dato che la ricerca PubMed ha evidenziato correlazioni con disordini tiroidei (PMID 2237677) ed esordi precoci (PMID 10408070), assicurati di specificare questi aspetti se presenti.
#
# ---
#
# #### 5. Informazioni sul Paziente
# - **Età/Sesso:** [Esempio: Donna, 48 anni]
# - **Occupazione:** [Importante per stress meccanico sulle mani]
# - **Sintomo Principale:** [Esempio: Dolore e tumefazione nodulare alle dita da 6 mesi]
# - **Storia Familiare:** [Presente/Assente]
#
# #### 6. Reperti Clinici
# - **Ispezione:** [Noduli duri a livello delle articolazioni interfalangee distali (DIP), deviazione ulnare?]
# - **Palpazione:** [Dolorabilità, calore, consistenza]
#
# #### 8. Valutazione Diagnostica
# - **Laboratorio:** [PCR, FR, Anti-CCP - per escludere AR; TSH/FT4 - per screening tiroideo]
# - **Imaging:** [Descrizione RX: osteofiti marginali, sclerosi subcondrale]
#
# #### 9. Intervento Terapeutico
# - **Trattamento:** [FANS topici/orali, tutori, educazione ergonomica]

# %% [markdown]
# ### 🖋️ Sezione: Discussione (CARE Checklist 11)
#
# #### Tabella di Confronto
#
# | Parametro | Tuo Paziente | Caso Giovane (PMID 10408070) | Studio Premenopausa (PMID 2237677) |
# |---|---|---|---|
# | **Età all'esordio** | [Inserire] | 12 anni | Premenopausa |
# | **Sesso** | [M/F] | Maschio | Femmine (n=9) |
# | **Associazioni Tiroidee** | [Sì/No] | Non riportate | Presenti (100% dei casi) |
# | **Ereditarietà** | [Sì/No] | Consistente | Studiata |
#
# ---
#
# #### Bozze per la Discussione
#
# **1. Sintesi dei Risultati:**
# Il presente caso descrive una manifestazione di noduli di Heberden in [Età/Sesso] con [descrizione breve dei sintomi]. La diagnosi è stata supportata da evidenze radiografiche di osteoartrosi delle articolazioni interfalangee distali, escludendo altre patologie infiammatorie come l'artrite reumatoide.
#
# **2. Confronto con la Letteratura:**
# Sebbene i noduli di Heberden siano tipici delle donne in post-menopausa, la letteratura riporta casi rari di insorgenza precoce. Rascu et al. (PMID 10408070) hanno documentato un esordio a soli 12 anni in un maschio, suggerendo che fattori genetici possano sovvertire il tipico profilo epidemiologico.
#
# *Opzionale (se il paziente ha problemi tiroidei):*
# In linea con quanto osservato da Yoshino et al. (PMID 2237677), che hanno riscontrato disordini tiroidei (come il morbo di Basedow o la tiroidite di Hashimoto) nel 100% delle pazienti con esordio in pre-menopausa, il nostro paziente presentava [dettaglio tiroideo], rafforzando l'ipotesi di un legame endocrino-metabolico.
#
# **3. Punti di Forza e Limiti:**
# Il punto di forza di questo report è la documentazione completa [es. iconografica/biochimica]. Un limite è rappresentato dalla natura di singolo case report, che non permette di stabilire nessi causali definitivi.

# %% [markdown]
# ### 🔍 Focus: Influenza delle Associazioni Tiroidee sul Profilo Clinico
#
# Basandoci sull'analisi degli abstract (in particolare **PMID 2237677**), ecco come i disordini tiroidei possono influenzare il profilo del paziente:
#
# 1. **Marker di Esordio Precoce:** Nello studio citato, il 100% delle pazienti (9 su 9) con insorgenza di noduli in età pre-menopausale presentava una disfunzione tiroidea (6 Morbo di Basedow, 2 Tiroidite di Hashimoto, 1 Granulare).
# 2. **Sospetto Sistemico:** Se il tuo paziente è giovane o in pre-menopausa, la presenza di noduli di Heberden non dovrebbe essere vista solo come 'usura' meccanica, ma come un segnale per controllare i livelli di **TSH, FT4 e anticorpi anti-tiroide**.
# 3. **Gestione Clinica:** La letteratura suggerisce che queste pazienti non hanno necessariamente altri fattori di rischio classici (come traumi o artrite reumatoide), indicando che lo squilibrio metabolico/ormonale legato alla tiroide potrebbe accelerare la degenerazione della cartilagine interfalangea.
#
# **Conseguenza per il tuo Case Report:**
# Se il tuo paziente ha una storia di distiroidismo, questo diventa l'elemento centrale della tua 'Discussione', trasformando un semplice caso di artrosi in un report di rilevanza endocrinologica.

# %%
# Recupero abstract dettagliati per gli articoli #7 e #13
target_pmids = '10408070,2237677'

# Costruiamo l'URL per efetch (modalità XML per i dettagli completi)
fetch_url = f"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id={target_pmids}&retmode=xml"

print(f"Analisi abstract in corso per PMIDs: {target_pmids}...")
# Passiamo l'output al parser in modalità 'efetch'
# !curl -s "{fetch_url}" | python3 {parser_path} efetch
# Out:
# Analisi abstract in corso per PMIDs: 10408070,2237677...
# ## PMID: 10408070
# **Title**: [An unusual case of Heberden arthrosis in a young man].
# **Authors**: Rascu A; Kraetsch H G; Grünke M; Kalden J R; Manger B
# **Journal**: Zeitschrift fur Rheumatologie (Z Rheumatol)
# **Year**: 1999  **Volume**: 58  **Issue**: 2  **Pages**: 95-9
# **DOI**:
# **Abstract**: Heberden nodes affect mainly middle-aged women. Inheritance is autosomal dominant in female and autosomal recessive in male patients. We report the case of a young man who presented already with 12 years of age with pain in the distal finger joints. There were no other clinical or serological signs for other rheumatoid diseases, like psoriatic or rheumatoid arthritis. Radiologic findings were consistent with Heberden's osteoarthritis of the finger joints. The joint changes remained clinically...
#
# ## PMID: 2237677
# **Title**: [Clinical studies on 9 patients with Heberden's nodes of premenopausal onset].
# ...

# %%
research_agent.perform_search_parse('Noduli di Heberden')
# Out:
# Parsing PubMed results for: Noduli di Heberden
# Traceback (most recent call last):
#   File "/content/medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/search-lit/references/parse_pubmed.py", line 229, in <module>
#     data = sys.stdin.read()
#            ^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C

# %%
import os

# Visualizzazione rapida delle istruzioni principali
readme_path = 'medsci_skills_extracted/medsci-skills-classroom-v2.1.1/README_FIRST.md'
if os.path.exists(readme_path):
    with open(readme_path, 'r') as f:
        print("--- ESTRATTO README ---")
        print('\n'.join(f.readlines()[:20])) # Primi 20 righi
else:
    print('File README non trovato.')
# Out:
# --- ESTRATTO README ---
# # MedSci Skills Classroom Installer
#
#
#
# This ZIP is for non-programmer classroom installation.
#
#
#
# ## Windows
#
#
#
# 1. Unzip this folder.
#
# 2. Double-click `installers/install-windows.cmd`.
#
# 3. Restart Claude Code Desktop, Codex Desktop, or Cursor.
#
# 4. Paste this first test prompt:
#
#
#
# ```text
#
# MedSci Skills가 설치됐는지 확인하고, 오늘 실습에 쓸 대표 스킬 5개만 보여줘.
#
# ```
#
#
#
# If Windows shows a security warning, choose **More info** and then **Run anyway**.
#
# The installer copies the `skills/` folder into local agent skill folders and writes
#
# an install log in this folder.
#
#
#
# ## macOS

# %%
# Elenco dei template principali per la scrittura scientifica
# !ls medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/write-paper/references/paper_types/
print('\n--- Guide per Sezione ---')
# !ls medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/write-paper/references/section_guides/
# Out:
# ai_validation.md  cross_national.md  nhis_cohort.md
# animal_study.md   letter.md	     original_article.md
# case_report.md	  meta_analysis.md   technical_note.md
#
# --- Guide per Sezione ---
# discussion.md	 methods.md  step7_4a_audit_recovery.md
# introduction.md  results.md  title_abstract.md

# %%
# Ispezione del parser per capire come accetta gli argomenti
with open('medsci_skills_extracted/medsci-skills-classroom-v2.1.1/skills/search-lit/references/parse_pubmed.py', 'r') as f:
    lines = f.readlines()
    # Cerchiamo la sezione dedicata ad argparse o sys.argv
    for i, line in enumerate(lines):
        if 'import argparse' in line or 'sys.argv' in line or 'def main' in line:
            print(f"--- Line {i+1} ---")
            print(''.join(lines[max(0, i-2):i+15]))
# Out:
# --- Line 224 ---
#
# if __name__ == "__main__":
#     if len(sys.argv) < 2:
#         print(__doc__)
#         sys.exit(1)
#
#     mode = sys.argv[1]
#     data = sys.stdin.read()
#
#     dispatch = {
#         "esearch": parse_esearch,
#         "esummary": parse_esummary,
#         "efetch": parse_efetch,
#         "bibtex": generate_bibtex,
#     }
#
#     func = dispatch.get(mode)
#
# --- Line 228 ---
#         sys.exit(1)
#
#     mode = sys.argv[1]
#     data = sys.stdin.read()
#
#     dispatch = {
#         "esearch": parse_esearch,
#         "esummary": parse_esummary,
#         "efetch": parse_efetch,
#         "bibtex": generate_bibtex,
#     }
#
#     func = dispatch.get(mode)
#     if func is None:
#         print(f"Unknown mode: {mode}. Use: {', '.join(dispatch.keys())}")
#         sys.exit(1)
