# %% [markdown]
# <a href="https://colab.research.google.com/github/venezianof/booksum/blob/main/DeepMedricerca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
if os.path.exists('deepmed-search'):
    # !rm -rf deepmed-search
# !git clone https://github.com/hint-lab/deepmed-search.git
# Out:
# Cloning into 'deepmed-search'...
# remote: Enumerating objects: 16045, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 16045 (delta 57), reused 79 (delta 39), pack-reused 15920 (from 2)
# Receiving objects: 100% (16045/16045), 100.24 MiB | 25.21 MiB/s, done.
# Resolving deltas: 100% (5045/5045), done.

# %%
# !cat /content/deepmed-search/package.json
# Out:
# cat: /content/deepmed-search/package.json: No such file or directory

# %%
import os
print(f'Current working directory: {os.getcwd()}')
# !ls -la
# Out:
# Current working directory: /content
# total 16
# drwxr-xr-x 1 root root 4096 Apr 16 13:28 .
# drwxr-xr-x 1 root root 4096 May  5 15:57 ..
# drwxr-xr-x 4 root root 4096 Apr 16 13:28 .config
# drwxr-xr-x 1 root root 4096 Apr 16 13:28 sample_data

# %%
# !ls -d /content/deepmed-search
# Out:
# ls: cannot access '/content/deepmed-search': No such file or directory

# %%
# !git clone https://github.com/hint-lab/deepmed-search.git
# Out:
# Cloning into 'deepmed-search'...
# remote: Enumerating objects: 16045, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 16045 (delta 57), reused 79 (delta 39), pack-reused 15920 (from 2)
# Receiving objects: 100% (16045/16045), 100.24 MiB | 25.41 MiB/s, done.
# Resolving deltas: 100% (5045/5045), done.

# %%
import os
project_path = '/content/deepmed-search'
os.chdir(project_path)
print(f'Current working directory: {os.getcwd()}')
# Out:
# Current working directory: /content/deepmed-search

# %%
# !npm install --legacy-peer-deps
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇
# ...

# %% [markdown]
# ### 🚀 Guida Rapida per l'Avvio
#
# 1. **Configurazione API**: Una volta terminata l'installazione dei pacchetti, dovremo creare un file `.env.local` inserendo le tue chiavi API (OpenAI e Jina).
# 2. **Inizializzazione Database**: Configureremo i servizi necessari (come Redis o database, se richiesti dal progetto).
# 3. **Compilazione**: Eseguiremo la compilazione del 'Worker' per gestire le ricerche.
# 4. **Avvio**: Lanceremo il server di sviluppo per rendere l'interfaccia accessibile.
#
# *Nota: Monitoreremo i log per assicurarci che tutto giri correttamente senza errori di connessione.*

# %%
import os
project_path = '/content/deepmed-search'
if os.path.exists(project_path):
    os.chdir(project_path)
    print(f'Current working directory: {os.getcwd()}')
else:
    print('Directory not found. Please ensure the git clone step was successful.')
# Out:
# Current working directory: /content/deepmed-search

# %%
# Avvio del server di sviluppo in background
import subprocess
try:
    process = subprocess.Popen(['npm', 'run', 'dev'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print('Server di sviluppo avviato in background.')
except Exception as e:
    print(f'Errore durante l\'avvio: {e}')
# Out:
# Server di sviluppo avviato in background.

# %%
import os
project_path = '/content/deepmed-search'
os.chdir(project_path)
print(f'Current working directory: {os.getcwd()}')
# Out:
# Current working directory: /content/deepmed-search

# %%
# !npm install --legacy-peer-deps
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇
# ...

# %%
# !cp .env.example .env.local

# %%
# %%writefile .env.local
# # IMPORTANT: Replace 'your_openai_api_key_here' and 'your_jina_api_key_here' with your actual API keys.
# DATABASE_URL="postgresql://postgres:postgres@localhost:5432/deepmed"
# NEXTAUTH_URL="http://localhost:3000"
# NEXTAUTH_SECRET="your-secret-key"
# ENCRYPTION_KEY="your-encryption-key-32-chars"
# REDIS_URL="redis://localhost:6379"
# OPENAI_API_KEY="your_openai_api_key_here"
# JINA_API_KEY="your_jina_api_key_here"
# Out:
# Writing .env.local

# %%
# Start the web application in the background
import subprocess
subprocess.Popen(['npm', 'run', 'dev'])
# Out:
# <Popen: returncode: None args: ['npm', 'run', 'dev']>

# %%
# Re-install tsup and rebuild the worker
# !npm install tsup --legacy-peer-deps
# !npx tsup src/worker/index.ts --format cjs --platform=node --tsconfig tsconfig.worker.json --out-dir dist --clean
print('\nWorker ricompilato con successo.')
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇
# ...

# %% [markdown]
# # System Architecture
#
# ```mermaid
# graph TD
#     Frontend[Next.js Frontend] --> Backend[Server Actions]
#     Backend --> Queue[BullMQ Queue System]
#     Backend --> PG[PostgreSQL]
#     Backend --> Milvus[Milvus Vector DB]
#     Queue --> Worker[Queue Worker]
#     Worker --> External[External APIs]
#     External --> LLM[LLM Providers]
#     External --> Search[Search APIs]
#     External --> Parser[Document Parsers]
# ```

# %%
# !cat /content/deepmed-search/logs/all.log
# Out:
# 2025-05-05 19:48:36:4836 info: 初始化 Redis 客户端，连接至: localhost:6379
# 2025-05-05 19:48:36:4836 error: 错误: LLM_PROVIDER 是 'openai' 但 OPENAI_API_KEY 未设置。
# 2025-05-05 19:48:36:4836 warn: 警告: SEARCH_PROVIDER 是 'jina' 但 JINA_API_KEY 未设置。
# 2025-05-05 19:48:36:4836 info: 有效配置摘要 (来自环境变量或默认值):
# 2025-11-09 12:32:45:3245 info: [KB Maintenance] Starting vector resync
# 2025-11-09 12:33:04:334 info: [KB Maintenance] Starting vector resync
# 2025-11-10 21:51:56:5156 info: [ProviderFactory] Creating new provider: deepseek
# 2026-05-05 05:01:04:14 info: 初始化 Redis 客户端（从 REDIS_HOST/PORT），连接至: localhost:6379
# 2026-05-05 05:01:05:15 info: [Research Worker] Research Worker 已启动
# 2026-05-05 05:01:05:15 info: [Chunk Worker] Chunk Worker 已启动

# %%
# Kill existing background processes and restart
# !pkill -f "node" || true
# !pkill -f "npm" || true

import subprocess
import time

print("Restarting Web Application...")
subprocess.Popen(['npm', 'run', 'dev'])

time.sleep(5)  # Brief pause to let the dev server initialize

print("Restarting Queue Worker...")
subprocess.Popen(['node', 'dist/index.cjs'])

print("Processes restarted with updated environment variables.")

# %%
import subprocess
import time
import os

project_path = '/content/deepmed-search'

# 1. Clean up existing processes
# !pkill -f "node" || true
# !pkill -f "npm" || true

print(f'Working directory for subprocesses: {project_path}')

# 2. Start Dev Server
print('Starting dev server...')
with open('/content/dev_stdout.log', 'w') as out, open('/content/dev_stderr.log', 'w') as err:
    subprocess.Popen(['npm', 'run', 'dev'], stdout=out, stderr=err, text=True, cwd=project_path, shell=True)

# 3. Start Worker
print('Starting worker...')
with open('/content/worker_stdout.log', 'w') as out, open('/content/worker_stderr.log', 'w') as err:
    subprocess.Popen(['node', 'dist/index.cjs'], stdout=out, stderr=err, text=True, cwd=project_path, shell=True)

time.sleep(10)  # Wait for 10 seconds as requested

# Verify immediate file creation
print('\nVerifying log files:')
for f in ['dev_stdout.log', 'dev_stderr.log', 'worker_stdout.log', 'worker_stderr.log']:
    exists = os.path.exists(f'/content/{f}')
    size = os.path.getsize(f'/content/{f}') if exists else 0
    print(f'- {f}: {"Created" if exists else "NOT CREATED"} ({size} bytes)')

# %%
# !tail -n 20 /content/deepmed-search/logs/all.log

# %%
import os
import subprocess

# Check for any log files in the project
print('Searching for log files...')
# !find /content/deepmed-search -name "*.log"

# Check if processes are running with specific details
print('\nChecking active Node processes:')
# !ps -ef | grep node

# Try to read the last few lines of stdout from the background processes if possible
# (Note: subprocess.PIPE output is generally consumed by the parent, but we can check existence)
project_path = '/content/deepmed-search'
if not os.path.exists(os.path.join(project_path, 'logs')):
    print(f'\nCreating logs directory manually to see if it helps: {project_path}/logs')
    os.makedirs(os.path.join(project_path, 'logs'), exist_ok=True)
# Out:
# Searching for log files...
# find: ‘/content/deepmed-search’: No such file or directory
#
# Checking active Node processes:
# root           6       1  1 05:35 ?        00:00:00 /tools/node/bin/node /datalab/web/app.js
# root         157       6  0 05:35 ?        00:00:00 /usr/colab/bin/language_service -- node /datalab/web/pyright/pyright-langserver.js --stdio --cancellationReceive=file:682a1ef46d4edbf48ba03a4fca6837f04abe53460a
# root         165     157 12 05:35 ?        00:00:04 node /datalab/web/pyright/pyright-langserver.js --stdio --cancellationReceive=file:682a1ef46d4edbf48ba03a4fca6837f04abe53460a
# root         330     130  0 05:35 ?        00:00:00 /bin/bash -c ps -ef | grep node
# root         332     330  0 05:35 ?        00:00:00 grep node
#
# Creating logs directory manually to see if it helps: /content/deepmed-search/logs

# %%
# !ls -la /content/
# Verifichiamo se per caso è dentro una sottocartella o se il nome è leggermente diverso
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Apr 16 13:28 .
# drwxr-xr-x 1 root root 4096 May  5 05:36 ..
# drwxr-xr-x 4 root root 4096 Apr 16 13:28 .config
# drwxr-xr-x 1 root root 4096 Apr 16 13:28 sample_data

# %%
# !ls -la /content/deepmed-search
# !ls -la /content/deepmed-search/logs || echo 'Logs directory not found'
# !tail -n 20 /content/deepmed-search/logs/all.log || echo 'Log file not found'
# Out:
# ls: cannot access '/content/deepmed-search': No such file or directory
# ls: cannot access '/content/deepmed-search/logs': No such file or directory
# Logs directory not found
# tail: cannot open '/content/deepmed-search/logs/all.log' for reading: No such file or directory
# Log file not found

# %%
import os
# Check the temporary stdout/stderr logs created by Popen
files_to_check = ['dev_stdout.log', 'dev_stderr.log', 'worker_stdout.log', 'worker_stderr.log']

for f_name in files_to_check:
    if os.path.exists(f_name):
        print(f'\n--- Content of {f_name} ---')
        with open(f_name, 'r') as f:
            print(f.read())
    else:
        print(f'File {f_name} not found.')

# Also check if the app created logs in a different relative path
print('\nSearching for any .log files in /content/deepmed-search/ (recursive):')
# !find /content/deepmed-search/ -name "*.log"
# Out:
# File dev_stdout.log not found.
# File dev_stderr.log not found.
# File worker_stdout.log not found.
# File worker_stderr.log not found.
#
# Searching for any .log files in /content/deepmed-search/ (recursive):
# find: ‘/content/deepmed-search/’: No such file or directory

# %% [markdown]
# ### 🛠️ Monitoraggio Semplificato
# Esegui questa cella per vedere lo stato dei processi e gli eventuali errori in tempo reale.

# %%
import os
import time

def check_logs():
    print("--- STATO PROCESSI ---")
    # !ps -ef | grep -E 'node|npm' | grep -v grep

    log_files = [
        '/content/dev_stdout.log',
        '/content/dev_stderr.log',
        '/content/worker_stdout.log',
        '/content/worker_stderr.log'
    ]

    for log in log_files:
        print(f"\n--- Analisi file: {log} ---")
        if os.path.exists(log):
            size = os.path.getsize(log)
            if size > 0:
                with open(log, 'r') as f:
                    # Legge le ultime 20 righe
                    lines = f.readlines()
                    for line in lines[-20:]:
                        print(line.strip())
            else:
                print("Il file esiste ma è VUOTO (il processo non ha scritto nulla).")
        else:
            print("File non trovato. Il processo non è partito o non ha permessi di scrittura.")

check_logs()
# Out:
# --- STATO PROCESSI ---
# root           7       1  0 15:53 ?        00:00:00 /tools/node/bin/node /datalab/web/app.js
# root         159       7  0 15:53 ?        00:00:00 /usr/colab/bin/language_service -- node /datalab/web/pyright/pyright-langserver.js --stdio --cancellationReceive=file:3a76bd058d749be019b1083842af49e1f8ffa9bb28
# root         166     159  4 15:53 ?        00:00:05 node /datalab/web/pyright/pyright-langserver.js --stdio --cancellationReceive=file:3a76bd058d749be019b1083842af49e1f8ffa9bb28
#
# --- Analisi file: /content/dev_stdout.log ---
# File non trovato. Il processo non è partito o non ha permessi di scrittura.
#
# --- Analisi file: /content/dev_stderr.log ---
# File non trovato. Il processo non è partito o non ha permessi di scrittura.
#
# --- Analisi file: /content/worker_stdout.log ---
# File non trovato. Il processo non è partito o non ha permessi di scrittura.
#
# --- Analisi file: /content/worker_stderr.log ---
# ...

# %%
# Passaggio di debug 1: Verificare l'esistenza del file del worker
# !ls -l /content/deepmed-search/dist/index.cjs
# Out:
# ls: cannot access '/content/deepmed-search/dist/index.cjs': No such file or directory

# %%
# Passaggio di debug 2: Eseguire il server di sviluppo (npm run dev) in modo sincrono per vedere l'output diretto
import os
project_path = '/content/deepmed-search'

print(f'Running npm run dev from {project_path}')

# Uccidi processi preesistenti per una partenza pulita
# !pkill -f "node" || true
# !pkill -f "npm" || true

# Esegui npm run dev in modo bloccante e cattura l'output
import subprocess
try:
    result = subprocess.run(['npm', 'run', 'dev'], cwd=project_path, check=True, capture_output=True, text=True, shell=True)
    print("npm run dev - STDOUT:")
    print(result.stdout)
    print("npm run dev - STDERR:")
    print(result.stderr)
except subprocess.CalledProcessError as e:
    print(f"Errore durante l'esecuzione di npm run dev: {e}")
    print("STDOUT:")
    print(e.stdout)
    print("STDERR:")
    print(e.stderr)
except Exception as e:
    print(f"Si è verificato un errore inatteso: {e}")

# %%
# Passaggio di debug 3: Eseguire il worker (node dist/index.cjs) in modo sincrono per vedere l'output diretto
import os
project_path = '/content/deepmed-search'

print(f'Running worker from {project_path}')

# Uccidi processi preesistenti per una partenza pulita (in caso npm fosse rimasto appeso)
# !pkill -f "node" || true
# !pkill -f "npm" || true

# Esegui node dist/index.cjs in modo bloccante e cattura l'output
import subprocess
try:
    result = subprocess.run(['node', 'dist/index.cjs'], cwd=project_path, check=True, capture_output=True, text=True, shell=True)
    print("Worker - STDOUT:")
    print(result.stdout)
    print("Worker - STDERR:")
    print(result.stderr)
except subprocess.CalledProcessError as e:
    print(f"Errore durante l'esecuzione del worker: {e}")
    print("STDOUT:")
    print(e.stdout)
    print("STDERR:")
    print(e.stderr)
except Exception as e:
    print(f"Si è verificato un errore inatteso: {e}")

# %%
# !ls -la /content/deepmed-search
# Out:
# ls: cannot access '/content/deepmed-search': No such file or directory

# %%
# !tail -n 20 /content/deepmed-search/logs/error.log
# Out:
# 2025-05-05 19:48:36:4836 error: 错误: LLM_PROVIDER 是 'openai' 但 OPENAI_API_KEY 未设置。

# %%
# !tail -n 20 /content/deepmed-search/logs/all.log
# Out:
# 2025-05-05 19:48:36:4836 info: 初始化 Redis 客户端，连接至: localhost:6379
# 2025-05-05 19:48:36:4836 error: 错误: LLM_PROVIDER 是 'openai' 但 OPENAI_API_KEY 未设置。
# 2025-05-05 19:48:36:4836 warn: 警告: SEARCH_PROVIDER 是 'jina' 但 JINA_API_KEY 未设置。
# 2025-05-05 19:48:36:4836 info: 有效配置摘要 (来自环境变量或默认值):
# 2025-11-09 12:32:45:3245 info: [KB Maintenance] Starting vector resync
# 2025-11-09 12:33:04:334 info: [KB Maintenance] Starting vector resync
# 2025-11-10 21:51:56:5156 info: [ProviderFactory] Creating new provider: deepseek

# %%
import subprocess
import time
import os

project_path = '/content/deepmed-search'
os.chdir(project_path)

print('1. Arresto dei processi in corso...')
# !pkill -f "node" || true
# !pkill -f "npm" || true
time.sleep(2)

print('2. Riavvio del Server di Sviluppo (Next.js)...')
with open('/content/dev_stdout.log', 'w') as out, open('/content/dev_stderr.log', 'w') as err:
    subprocess.Popen(['npm', 'run', 'dev'], stdout=out, stderr=err, text=True, cwd=project_path, shell=True)

print('3. Riavvio del Research Worker...')
with open('/content/worker_stdout.log', 'w') as out, open('/content/worker_stderr.log', 'w') as err:
    subprocess.Popen(['node', 'dist/index.cjs'], stdout=out, stderr=err, text=True, cwd=project_path, shell=True)

time.sleep(5)
print('\n✅ Processi riavviati. Controlla la cella successiva per i log.')

# %%
# Verifica immediata dei log per errori di configurazione
print('--- Ultime righe dal log del Worker ---')
# !tail -n 20 /content/deepmed-search/logs/all.log
# Out:
# --- Ultime righe dal log del Worker ---
# tail: cannot open '/content/deepmed-search/logs/all.log' for reading: No such file or directory

# %%
import os
import subprocess

# 1. Verifica se la cartella del progetto esiste ancora
project_path = '/content/deepmed-search'
if os.path.exists(project_path):
    print(f'✅ Cartella progetto trovata: {project_path}')
    # 2. Cerca file di log ricorsivamente
    print('\nRicerca file di log in corso...')
    # !find {project_path} -name "*.log"

    # 3. Verifica i processi attivi
    print('\nVerifica processi Node/NPM attivi:')
    # !ps -ef | grep -E 'node|npm' | grep -v grep
else:
    print(f'❌ Errore: La cartella {project_path} non esiste. Verifichiamo il contenuto di /content/')
    # !ls -la /content/
# Out:
# ❌ Errore: La cartella /content/deepmed-search non esiste. Verifichiamo il contenuto di /content/
# total 16
# drwxr-xr-x 1 root root 4096 Apr 16 13:28 .
# drwxr-xr-x 1 root root 4096 May  5 16:24 ..
# drwxr-xr-x 4 root root 4096 Apr 16 13:28 .config
# drwxr-xr-x 1 root root 4096 Apr 16 13:28 sample_data

# %%
import os
# 1. Re-clone the repository
if not os.path.exists('/content/deepmed-search'):
    print('Cloning repository...')
    # !git clone https://github.com/hint-lab/deepmed-search.git

# 2. Enter directory and setup .env.local
project_path = '/content/deepmed-search'
os.chdir(project_path)
if not os.path.exists('.env.local'):
    # !cp .env.example .env.local
    print('File .env.local creato. Ricordati di inserire le tue chiavi API!')

# 3. Quick check
# !ls -la
# Out:
# total 944
# drwxr-xr-x 15 root root   4096 May  5 16:25 .
# drwxr-xr-x  1 root root   4096 May  5 16:25 ..
# -rw-r--r--  1 root root    473 May  5 16:25 components.json
# -rw-r--r--  1 root root    241 May  5 16:25 .cursorignore
# drwxr-xr-x  5 root root   4096 May  5 16:25 docker
# -rw-r--r--  1 root root  11350 May  5 16:25 docker-compose.demo.yml
# -rw-r--r--  1 root root  11726 May  5 16:25 docker-compose.yml
# -rw-r--r--  1 root root   2895 May  5 16:25 Dockerfile
# -rw-r--r--  1 root root   2241 May  5 16:25 Dockerfile.worker
# -rw-r--r--  1 root root    771 May  5 16:25 .dockerignore
# drwxr-xr-x  6 root root   4096 May  5 16:25 docs
# -rw-r--r--  1 root root   3085 May  5 16:25 .env.example
# -rw-r--r--  1 root root   3085 May  5 16:25 .env.local
# -rw-r--r--  1 root root   2673 May  5 16:25 eslint.config.mjs
# drwxr-xr-x  8 root root   4096 May  5 16:25 .git
# drwxr-xr-x  3 root root   4096 May  5 16:25 .github
# -rw-r--r--  1 root root    267 May  5 16:25 .gitignore
# ...

# %%
# Inserisci qui le tue chiavi API
OPENAI_KEY = "inserisci_qui_la_tua_openai_key"
JINA_KEY = "inserisci_qui_la_tua_jina_key"

import os

file_path = '/content/deepmed-search/.env.local'

env_content = f"""DATABASE_URL=\"postgresql://postgres:postgres@localhost:5432/deepmed\"
NEXTAUTH_URL=\"http://localhost:3000\"
NEXTAUTH_SECRET=\"colab-secret-key-123\"
ENCRYPTION_KEY=\"a-32-char-encryption-key-123456\"
REDIS_URL=\"redis://localhost:6379\"
OPENAI_API_KEY=\"{OPENAI_KEY}\"
JINA_API_KEY=\"{JINA_KEY}\"
"""

with open(file_path, 'w') as f:
    f.write(env_content)

print(f"✅ File {file_path} aggiornato con successo!")
# Out:
# ✅ File /content/deepmed-search/.env.local aggiornato con successo!

# %%
import subprocess
import time
import os

project_path = '/content/deepmed-search'
if not os.path.exists(project_path):
    print('Cartella non trovata. Rieseguo il clone...')
    # !git clone https://github.com/hint-lab/deepmed-search.git

os.chdir(project_path)

print('1. Terminazione processi esistenti...')
# !pkill -f "node" || true
# !pkill -f "npm" || true
time.sleep(2)

print('2. Avvio Server di Sviluppo...')
# Usiamo file assoluti per i log
with open('/content/dev_stdout.log', 'w') as out, open('/content/dev_stderr.log', 'w') as err:
    subprocess.Popen(['npm', 'run', 'dev'], stdout=out, stderr=err, text=True, cwd=project_path, shell=True)

print('3. Avvio Worker di Ricerca...')
# Assicurati che dist/index.cjs esista, altrimenti compilalo
if not os.path.exists('dist/index.cjs'):
    print('Compilazione worker...')
    # !npx tsup src/worker/index.ts --format cjs --platform=node --tsconfig tsconfig.worker.json --out-dir dist

with open('/content/worker_stdout.log', 'w') as out, open('/content/worker_stderr.log', 'w') as err:
    subprocess.Popen(['node', 'dist/index.cjs'], stdout=out, stderr=err, text=True, cwd=project_path, shell=True)

time.sleep(10)
print('\n✅ Riavvio completato. Controlla di nuovo il Pannello di Debug.')
# Out:
# Cartella non trovata. Rieseguo il clone...
# Cloning into 'deepmed-search'...
# remote: Enumerating objects: 16045, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 16045 (delta 57), reused 79 (delta 39), pack-reused 15920 (from 2)
# Receiving objects: 100% (16045/16045), 100.24 MiB | 22.90 MiB/s, done.
# Resolving deltas: 100% (5045/5045), done.

# %%
from google.colab.output import eval_js

port = 3000
try:
    url = eval_js(f"google.colab.kernel.proxyPort({port})")
    print(f"🚀 Interfaccia Web pronta!")
    print(f"Clicca sul link qui sotto per aprire l'applicazione:")
    print(url)
except Exception as e:
    print(f"Errore nel generare il link: {e}")
# Out:
# 🚀 Interfaccia Web pronta!
# Clicca sul link qui sotto per aprire l'applicazione:
# https://3000-m-s-kkb-use1d2-jbjs304xr4wb-d.us-east1-2.prod.colab.dev

# %% [markdown]
# ### 🔍 Pannello di Debug in Tempo Reale
# Usa questa cella per ispezionare gli errori se l'interfaccia non carica o se le ricerche falliscono.

# %%
import os

def debug_deepmed():
    print('=== 1. STATO PROCESSI NODE ===')
    # !ps -ef | grep -E 'node|npm' | grep -v grep

    print('\n=== 2. ERRORI SERVER (Next.js) ===')
    if os.path.exists('/content/dev_stderr.log'):
        # !tail -n 20 /content/dev_stderr.log
    else:
        print('File dev_stderr.log non trovato.')

    print('\n=== 3. ERRORI WORKER (Research) ===')
    if os.path.exists('/content/worker_stderr.log'):
        # !tail -n 20 /content/worker_stderr.log
    else:
        print('File worker_stderr.log non trovato.')

    print('\n=== 4. LOG INTERNI APPLICAZIONE ===')
    log_path = '/content/deepmed-search/logs/all.log'
    if os.path.exists(log_path):
        # !tail -n 15 {log_path}
    else:
        print('Log all.log non ancora generato.')

debug_deepmed()
# Out:
# === 1. STATO PROCESSI NODE ===
# root           7       1  0 16:26 ?        00:00:00 /tools/node/bin/node /datalab/web/app.js
# root         193       7  0 16:27 ?        00:00:00 /usr/colab/bin/language_service -- node /datalab/web/pyright/pyright-langserver.js --stdio --cancellationReceive=file:c68007e29aee5f252a956e6a8f86c82b44d6248b57
# root         199     193 16 16:27 ?        00:00:09 node /datalab/web/pyright/pyright-langserver.js --stdio --cancellationReceive=file:c68007e29aee5f252a956e6a8f86c82b44d6248b57
#
# === 2. ERRORI SERVER (Next.js) ===
# File dev_stderr.log non trovato.
#
# === 3. ERRORI WORKER (Research) ===
# File worker_stderr.log non trovato.
#
# === 4. LOG INTERNI APPLICAZIONE ===
# Log all.log non ancora generato.

# %%
from google.colab.output import eval_js

port = 3000
try:
    url = eval_js(f"google.colab.kernel.proxyPort({port})")
    print(f"🚀 Link di Accesso Diretto:")
    print(url)
except Exception as e:
    print(f"Errore nel generare il link: {e}")
# Out:
# 🚀 Link di Accesso Diretto:
# https://3000-m-s-kkb-use1d2-jbjs304xr4wb-d.us-east1-2.prod.colab.dev

# %%
import os
# 1. Re-clone the repository
if not os.path.exists('/content/deepmed-search'):
    print('Cloning repository...')
    # !git clone https://github.com/hint-lab/deepmed-search.git

# 2. Enter directory and setup .env.local
os.chdir('/content/deepmed-search')
if not os.path.exists('.env.local'):
    # !cp .env.example .env.local
    print('File .env.local creato. Ricordati di inserire le tue chiavi API!')

# 3. Quick check
# !ls -la
# Out:
# Cloning repository...
# Cloning into 'deepmed-search'...
# remote: Enumerating objects: 16045, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 16045 (delta 57), reused 79 (delta 39), pack-reused 15920 (from 2)
# Receiving objects: 100% (16045/16045), 100.24 MiB | 24.32 MiB/s, done.
# Resolving deltas: 100% (5045/5045), done.
# File .env.local creato. Ricordati di inserire le tue chiavi API!
# total 944
# drwxr-xr-x 15 root root   4096 May  5 16:25 .
# drwxr-xr-x  1 root root   4096 May  5 16:25 ..
# -rw-r--r--  1 root root    473 May  5 16:25 components.json
# -rw-r--r--  1 root root    241 May  5 16:25 .cursorignore
# drwxr-xr-x  5 root root   4096 May  5 16:25 docker
# -rw-r--r--  1 root root  11350 May  5 16:25 docker-compose.demo.yml
# -rw-r--r--  1 root root  11726 May  5 16:25 docker-compose.yml
# -rw-r--r--  1 root root   2895 May  5 16:25 Dockerfile
# ...

# %%
import os
import subprocess

# 1. Search for any log files
print('Searching for log files...')
# !find /content/deepmed-search -name "*.log"

# 2. Check active processes
print('\nActive processes (node/npm):')
# !ps -ef | grep -E 'node|npm' | grep -v grep

# 3. List directory content to verify structure
print('\nProject directory content:')
# !ls -F /content/deepmed-search
# Out:
# Searching for log files...
# find: ‘/content/deepmed-search’: No such file or directory
#
# Active processes (node/npm):
# root           7       1  1 16:24 ?        00:00:00 /tools/node/bin/node /datalab/web/app.js
# root         192       7  0 16:24 ?        00:00:00 /usr/colab/bin/language_service -- node /datalab/web/pyright/pyright-langserver.js --stdio --cancellationReceive=file:f70bb6b2f3a8acc3390f874f763d2f68bc43d0fbe0
# root         198     192 21 16:24 ?        00:00:05 node /datalab/web/pyright/pyright-langserver.js --stdio --cancellationReceive=file:f70bb6b2f3a8acc3390f874f763d2f68bc43d0fbe0
#
# Project directory content:
# ls: cannot access '/content/deepmed-search': No such file or directory

# %%
# !tail -n 50 /content/deepmed-search/logs/all.log
# Out:
# 2025-05-05 19:48:36:4836 info: 初始化 Redis 客户端，连接至: localhost:6379
# 2025-05-05 19:48:36:4836 error: 错误: LLM_PROVIDER 是 'openai' 但 OPENAI_API_KEY 未设置。
# 2025-05-05 19:48:36:4836 warn: 警告: SEARCH_PROVIDER 是 'jina' 但 JINA_API_KEY 未设置。
# 2025-05-05 19:48:36:4836 info: 有效配置摘要 (来自环境变量或默认值):
# 2025-11-09 12:32:45:3245 info: [KB Maintenance] Starting vector resync
# 2025-11-09 12:33:04:334 info: [KB Maintenance] Starting vector resync
# 2025-11-10 21:51:56:5156 info: [ProviderFactory] Creating new provider: deepseek

# %%
import os
project_path = '/content/deepmed-search'

# Re-clone if missing
if not os.path.exists(project_path):
    print('Re-cloning repository...')
    # !git clone https://github.com/hint-lab/deepmed-search.git

os.chdir(project_path)

# Quick environment fix
if not os.path.exists('.env.local'):
    # !cp .env.example .env.local

# Build worker if dist is missing
if not os.path.exists('dist/index.cjs'):
    print('Building worker...')
    # !npm install --legacy-peer-deps
    # !npx tsup src/worker/index.ts --format cjs --platform=node --tsconfig tsconfig.worker.json --out-dir dist --clean

print('Project ready for search execution.')
# Out:
# Re-cloning repository...
# Cloning into 'deepmed-search'...
# remote: Enumerating objects: 16045, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 16045 (delta 57), reused 79 (delta 39), pack-reused 15920 (from 2)
# Receiving objects: 100% (16045/16045), 100.24 MiB | 24.64 MiB/s, done.
# Resolving deltas: 100% (5045/5045), done.
# Building worker...
# ...

# %% [markdown]
# ### Esecuzione della Ricerca Clinica
# Eseguiamo ora una ricerca automatizzata focalizzata sui casi clinici discussi (Prolasso della Valvola Mitrale e Malattie Interstiziali Polmonari).

# %%
import requests
import json
import time

# Nota: Questo script assume che il server Next.js sia attivo sulla porta 3000
# In alternativa, possiamo testare direttamente la logica del provider se il server non è raggiungibile

def run_medical_search(query):
    print(f'Eseguendo ricerca per: {query}')
    # Esempio di chiamata alla logica di ricerca o simulazione di inserimento in coda
    # In un ambiente Colab, monitoriamo il file di log per vedere la risposta del worker
    print('Check dei log in corso per catturare l\'attività del provider...')
    # !tail -n 10 /content/deepmed-search/logs/all.log

# Query basata sui dati medici precedenti
search_query = "Differential diagnosis for mid-systolic click and reticulo-nodular patterns in Sarcoidosis"
run_medical_search(search_query)

# %% [markdown]
# ### 🛠️ Procedura Semplificata: Avvio Rapido
# Esegui questa cella per configurare tutto e ottenere il link di accesso.

# %%
import os, subprocess, time
from google.colab.output import eval_js

project_path = '/content/deepmed-search'

# 1. Setup automatico
if not os.path.exists(project_path):
    print('Recupero file di progetto...')
    # !git clone https://github.com/hint-lab/deepmed-search.git

os.chdir(project_path)
if not os.path.exists('.env.local'):
    # !cp .env.example .env.local

# 2. Avvio processi
print('Avvio server e worker...')
# !pkill -f "node" || true
subprocess.Popen(['npm', 'run', 'dev'], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, shell=True)

# 3. Generazione Link
time.sleep(5)
try:
    url = eval_js("google.colab.kernel.proxyPort(3000)")
    print(f'\n🚀 APPLICAZIONE PRONTA!')
    print(f'Clicca qui per cercare: {url}')
except:
    print('Errore nella generazione del link. Riprova tra pochi secondi.')

# %% [markdown]
# ### 💾 Salvataggio Configurazione
# Esegui questa cella per scaricare il file `.env.local` sul tuo computer prima di chiudere.

# %%
from google.colab import files
import os

project_path = '/content/deepmed-search'

# Ripristino rapido se la cartella è sparita
if not os.path.exists(project_path):
    print('Ripristino cartella progetto...')
    # !git clone https://github.com/hint-lab/deepmed-search.git

config_path = os.path.join(project_path, '.env.local')
example_path = os.path.join(project_path, '.env.example')

if not os.path.exists(config_path):
    # !cp {example_path} {config_path}

print("Download del file .env.local in corso...")
files.download(config_path)
# Out:
# Ripristino cartella progetto...
# Cloning into 'deepmed-search'...
# remote: Enumerating objects: 16045, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 16045 (delta 57), reused 79 (delta 39), pack-reused 15920 (from 2)
# Receiving objects: 100% (16045/16045), 100.24 MiB | 21.38 MiB/s, done.
# Resolving deltas: 100% (5045/5045), done.
# Download del file .env.local in corso...

# %% [markdown]
# ### 🧠 Criteri Diagnostici DSM-5: Disturbo d'Ansia Generalizzato (GAD)
#
# Oltre al criterio temporale dei **6 mesi**, la diagnosi richiede:
#
# 1.  **Difficoltà nel controllare la preoccupazione**: L'individuo trova difficile gestire l'ansia.
# 2.  **Sintomi Associati** (almeno 3 dei seguenti per la maggior parte dei giorni):
#     *   Irrequietezza o sentirsi "con i nervi a fior di pelle".
#     *   Facile affaticabilità.
#     *   Difficoltà a concentrarsi o vuoti di memoria.
#     *   Irritabilità.
#     *   Tensione muscolare.
#     *   Alterazioni del sonno.
# 3.  **Compromissione Clinica**: I sintomi causano disagio significativo o menomazione nel funzionamento sociale, lavorativo o in altre aree importanti.
# 4.  **Esclusione**: Il disturbo non è dovuto agli effetti di una sostanza o di un'altra condizione medica e non è meglio spiegato da un altro disturbo mentale.

# %% [markdown]
# ### 🧠 Diagnosi Differenziale: Cefalee Trigemino-Autonomiche (TACs)
#
# Il caso clinico descritto punta all'**Emicrania Parossistica** grazie alla combinazione di durata e frequenza degli attacchi.
#
# | Caratteristica | Cefalea a Grappolo | Emicrania Parossistica | Sindrome SUNCT/SUNA |
# | :--- | :--- | :--- | :--- |
# | **Durata attacco** | 15 - 180 minuti | 2 - 30 minuti | 1 - 600 secondi |
# | **Frequenza** | 1 ogni 2 giorni - 8 al dì | > 5 al giorno (spesso > 20) | 3 - 200 al giorno |
# | **Sintomi Autonomici** | Presenti (omolaerali) | Presenti (omolaterali) | Molto marcati (lacrimazione/iniezione) |
# | **Sesso (M:F)** | 3:1 | 1:3 (più comune nelle donne) | 1.5:1 |
# | **Terapia d'elezione** | Triptani / Ossigeno | **Indometacina** (Risposta 100%) | Lamotrigina / Gabapentin |
#
# **Perché non le altre?**
# * **Sindrome SUNCT**: Gli attacchi sono troppo brevi (secondi) e solitamente più frequenti.
# * **Cefalea a Grappolo**: Gli attacchi durano più a lungo (minimo 15 min) e sono meno frequenti.
# * **Nevralgia del Trigemino**: Il dolore è a "scossa elettrica" di pochissimi secondi, solitamente scatenato da trigger cutanei e senza sintomi autonomici così marcati.

# %% [markdown]
# ### ⚽ Gestione Acuta della Lussazione di Rotula
#
# Nel contesto di un trauma sportivo con spostamento rotuleo, l'iter corretto è:
#
# 1.  **Riduzione Manuale**: È la prima misura da adottare. Si esegue portando l'arto in estensione e guidando la rotula verso la sua sede naturale (solitamente spostata lateralmente).
# 2.  **Immobilizzazione**: Applicazione di un tutore (spesso in estensione) per permettere la guarigione dei tessuti molli (legamento alare mediale).
# 3.  **Imaging (Post-riduzione)**: RX o Risonanza Magnetica per valutare eventuali distacchi osteocondrali o corpi mobili endoarticolari.
# 4.  **Riabilitazione**: Fondamentale il rinforzo del muscolo vasto mediale obliquo per prevenire recidive.

# %% [markdown]
# # 🧬 Medical Research Agent (Medline/PubMed)
# Questo agente permette di interrogare il database PubMed, estrarre metadati bibliografici e visualizzare abstract dettagliati.

# %%
# !pip install biopython pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 43.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from Bio import Entrez
import datetime

def medical_search_agent(query, max_results=5):
    # Configurazione Entrez (PubMed richiede un'email)
    Entrez.email = 'your_email@example.com'

    print(f'🔍 Ricerca in corso su PubMed per: {query}...\n')

    # 1. Ricerca degli ID degli articoli
    handle = Entrez.esearch(db='pubmed', term=query, retmax=max_results)
    record = Entrez.read(handle)
    handle.close()

    id_list = record['IdList']
    if not id_list:
        return 'Nessun risultato trovato.'

    # 2. Recupero dei dettagli degli articoli
    handle = Entrez.efetch(db='pubmed', id=','.join(id_list), rettype='xml', retmode='text')
    details = Entrez.read(handle)
    handle.close()

    results = []
    for article in details['PubmedArticle']:
        medline = article['MedlineCitation']
        article_data = medline['Article']

        title = article_data.get('ArticleTitle', 'Nessun titolo')
        journal = article_data['Journal'].get('Title', 'Nessun giornale')
        pmid = str(medline['PMID'])
        abstract = article_data.get('Abstract', {}).get('AbstractText', ['Nessun abstract'])[0]
        link = f'https://pubmed.ncbi.nlm.nih.gov/{pmid}/'

        results.append({
            'Titolo': title,
            'Giornale': journal,
            'Link': link,
            'Abstract': abstract[:500] + '...'
        })

    return pd.DataFrame(results)

# Esempio di utilizzo: Cerca studi sulla Sarcoidosi e pattern polmonari
query_test = 'Sarcoidosis reticulo-nodular patterns radiology'
df_results = medical_search_agent(query_test)
display(df_results)
# Out:
# 🔍 Ricerca in corso su PubMed per: Sarcoidosis reticulo-nodular patterns radiology...
#                                               Titolo  \
# 0  [The importance of thoracic CT in the diagnosi...
#
#                                             Giornale  \
# 0  RoFo : Fortschritte auf dem Gebiete der Rontge...
#
#                                        Link  \
# 0  https://pubmed.ncbi.nlm.nih.gov/2173063/
#
#                                             Abstract
# 0  The CT findings in the lungs of 52 patients wi...

# %% [markdown]
# ### 🖼️ Visualizzazione Immagini e Riassunti Dettagliati
# Puoi usare il DataFrame sopra per accedere ai link originali. Per le immagini mediche dettagliate (radiologia/istologia), l'agente può essere integrato con API come Open-i (NLM) o database specifici di imaging.

# %%
# Eseguiamo una nuova ricerca su un diverso argomento clinico
new_query = 'Mitral valve prolapse differential diagnosis click'
df_new_results = medical_search_agent(new_query)

display(df_new_results)
# Out:
# 🔍 Ricerca in corso su PubMed per: Mitral valve prolapse differential diagnosis click...
#                                               Titolo  \
# 0  The clicking chest: what exactly did Hamman he...
# 1  Regurgitant jet direction in patients with pro...
# 2       Current management of mitral valve prolapse.
# 3  [Infectious endocarditis in mitral valve prola...
# 4  The relationship between clinical and echocard...
#
#                                             Giornale  \
# 0               European heart journal. Case reports
# 1  Journal of cardiothoracic and vascular anesthesia
# 2                          American family physician
# 3  Revista de medicina interna, neurologe, psihia...
# 4                                               Herz
#
#                                         Link  \
# 0  https://pubmed.ncbi.nlm.nih.gov/33442622/
# 1  https://pubmed.ncbi.nlm.nih.gov/17678792/
# 2  https://pubmed.ncbi.nlm.nih.gov/10865929/
# 3   https://pubmed.ncbi.nlm.nih.gov/1978392/
# ...

# %%
# Ricerca delle linee guida sulla fibrillazione atriale
af_query = 'atrial fibrillation clinical practice guidelines 2023 2024'
df_af_results = medical_search_agent(af_query)

display(df_af_results)
# Out:
# 🔍 Ricerca in corso su PubMed per: atrial fibrillation clinical practice guidelines 2023 2024...
#                                               Titolo  \
# 0  Optimisation of heart failure management: insi...
# 1  The 2024 ESC guidelines on atrial fibrillation...
# 2  Education of healthcare professionals to impro...
# 3  Eligibility for Rapid Up-Titration of Guidelin...
# 4  [Sex-specific diagnostics and treatment of car...
#
#                           Giornale                                       Link  \
# 0                Acta cardiologica  https://pubmed.ncbi.nlm.nih.gov/41190602/
# 1  Internal and emergency medicine  https://pubmed.ncbi.nlm.nih.gov/40514614/
# 2                  Nature medicine  https://pubmed.ncbi.nlm.nih.gov/40514462/
# 3                       Cardiology  https://pubmed.ncbi.nlm.nih.gov/40293440/
# 4                             Herz  https://pubmed.ncbi.nlm.nih.gov/40116939/
#
#                                             Abstract
# ...

# %%
import pandas as pd

# Visualizzazione dettagliata degli abstract per le linee guida AF 2024
if 'df_af_results' in globals():
    print("--- DETTAGLI LINEE GUIDA AF 2024 ---\n")
    for index, row in df_af_results.iterrows():
        print(f"📌 TITOLO: {row['Titolo']}")
        print(f"📰 GIORNALE: {row['Giornale']}")
        print(f"🔗 LINK: {row['Link']}")
        print(f"📝 ABSTRACT:\n{row['Abstract']}")
        print("-" * 80 + "\n")
else:
    print("DataFrame df_af_results non trovato. Riesegui la ricerca precedente.")

# %%
import pandas as pd

# Eseguo la ricerca specifica per l'adenoma surrenalico richiesto dall'utente
adrenal_query = 'Adrenal adenoma clinical management diagnosis Cushing'
df_adrenal_results = medical_search_agent(adrenal_query, max_results=5)

print("--- RISULTATI RICERCA ADENOMA SURRENALICO ---\n")
display(df_adrenal_results)
# Out:
# 🔍 Ricerca in corso su PubMed per: Adrenal adenoma clinical management diagnosis Cushing...
#
# --- RISULTATI RICERCA ADENOMA SURRENALICO ---
#                                               Titolo  \
# 0           Natural history of large adrenal tumors.
# 1  Adrenal adenomata displaying mild autonomous c...
# 2  Endocrine hypertension: the role of imaging in...
# 3  Primary Bilateral Macronodular Adrenal Hyperpl...
# 4  Case Reports: Exploring the Varied Presentatio...
#
#                                             Giornale  \
# 0                         Frontiers in endocrinology
# 1          Cardiovascular endocrinology & metabolism
# 2                   The British journal of radiology
# 3                                  JCEM case reports
# 4  Journal of clinical research in pediatric endo...
#
#                                         Link  \
# 0  https://pubmed.ncbi.nlm.nih.gov/41788772/
# 1  https://pubmed.ncbi.nlm.nih.gov/41783764/
# ...

# %%
# Recupero e visualizzazione dell'abstract completo del secondo articolo
article_index = 1  # Indice dell'articolo sulla secrezione autonoma
if 'df_adrenal_results' in globals() and len(df_adrenal_results) > article_index:
    selected_article = df_adrenal_results.iloc[article_index]
    print(f"--- APPROFONDIMENTO ABSTRACT ---")
    print(f"TITOLO: {selected_article['Titolo']}")
    print(f"GIORNALE: {selected_article['Giornale']}")
    print(f"\nABSTRACT COMPLETO:\n{selected_article['Abstract']}")
    print(f"\nLINK PUBMED: {selected_article['Link']}")
else:
    print("Dati non trovati. Assicurati che la cella di ricerca sia stata eseguita correttamente.")
# Out:
# --- APPROFONDIMENTO ABSTRACT ---
# TITOLO: Adrenal adenomata displaying mild autonomous cortisol secretion: a service evaluation of cardiometabolic profile routinely screened patients.
# GIORNALE: Cardiovascular endocrinology & metabolism
#
# ABSTRACT COMPLETO:
# A proportion of adrenal adenomata exhibit autonomous cortisol secretion, now termed mild autonomous cortisol secretion (MACS), as defined by post-1mg overnight dexamethasone suppression test (ONDST) cortisol 51-137 nmol/l. Here, we characterized the cardiometabolic profile of MACS....
#
# LINK PUBMED: https://pubmed.ncbi.nlm.nih.gov/41783764/

# %%
def image_resource_finder(query):
    # Search for articles specifically mentioning imaging modalities
    image_query = f'{query} AND (image OR figure OR radiology OR CT OR MRI)'
    print(f'🔍 Ricerca di risorse visive per: {query}\n')

    # Re-use the existing search agent
    df_images = medical_search_agent(image_query, max_results=3)

    # Provide the direct link to Open-i for visualization
    print('\n&#128161; Suggerimento: Per visualizzare direttamente le immagini mediche, visita:')
    print(f'https://openi.nlm.nih.gov/gridquery?q={query.replace(" ", "+")}')

    return df_images

# Execution for Adrenal Adenoma
img_results = image_resource_finder('Adrenal adenoma CT scan Cushing')
display(img_results)
# Out:
# 🔍 Ricerca di risorse visive per: Adrenal adenoma CT scan Cushing
#
# 🔍 Ricerca in corso su PubMed per: Adrenal adenoma CT scan Cushing AND (image OR figure OR radiology OR CT OR MRI)...
#
#
# &#128161; Suggerimento: Per visualizzare direttamente le immagini mediche, visita:
# https://openi.nlm.nih.gov/gridquery?q=Adrenal+adenoma+CT+scan+Cushing
#                                               Titolo  \
# 0           Natural history of large adrenal tumors.
# 1  Endocrine hypertension: the role of imaging in...
# 2  A Novel <i>ARMC5</i> Germline Variant in Sibli...
#
#                            Giornale  \
# 0        Frontiers in endocrinology
# 1  The British journal of radiology
# 2                 JCEM case reports
#
#                                         Link  \
# 0  https://pubmed.ncbi.nlm.nih.gov/41788772/
# 1  https://pubmed.ncbi.nlm.nih.gov/41652884/
# 2  https://pubmed.ncbi.nlm.nih.gov/40895499/
#
#                                             Abstract
# ...

# %%
# Confronto dei titoli degli articoli trovati
if 'df_adrenal_results' in globals():
    print("--- ANALISI COMPARATIVA DEI TITOLI ---\n")
    for i, title in enumerate(df_adrenal_results['Titolo']):
        print(f"{i+1}. {title}")
else:
    print("Errore: DataFrame 'df_adrenal_results' non trovato.")
# Out:
# --- ANALISI COMPARATIVA DEI TITOLI ---
#
# 1. Natural history of large adrenal tumors.
# 2. Adrenal adenomata displaying mild autonomous cortisol secretion: a service evaluation of cardiometabolic profile routinely screened patients.
# 3. Endocrine hypertension: the role of imaging in diagnosis and management.
# 4. Primary Bilateral Macronodular Adrenal Hyperplasia Associated With <i>ARMC5</i> Variant and Pituitary Microadenoma.
# 5. Case Reports: Exploring the Varied Presentations and Clinical Features of Carney Complex, A Detailed Report on Three Distinct Cases.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Prepare data: count titles per journal
journal_counts = df_adrenal_results['Giornale'].value_counts().reset_index()
journal_counts.columns = ['Giornale', 'Numero di Articoli']

# Create the plot
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")
ax = sns.barplot(x='Numero di Articoli', y='Giornale', data=journal_counts, palette='viridis', hue='Giornale', legend=False)

plt.title('Distribuzione degli Articoli per Giornale (Adenoma Surrenalico)', fontsize=14, fontweight='bold')
plt.xlabel('Numero di Articoli', fontsize=12)
plt.ylabel('Giornale', fontsize=12)

# Add labels to bars
for i in ax.containers:
    ax.bar_label(i, padding=3)

plt.tight_layout()
plt.show()

# %%
first_article = df_adrenal_results.iloc[0]
print(f'--- ANALISI DETTAGLIATA ARTICOLO 1 ---')
print(f'TITOLO: {first_article["Titolo"]}')
print(f'GIORNALE: {first_article["Giornale"]}')
print(f'\nABSTRACT:\n{first_article["Abstract"]}')
print(f'\nLINK: {first_article["Link"]}')
# Out:
# --- ANALISI DETTAGLIATA ARTICOLO 1 ---
# TITOLO: Natural history of large adrenal tumors.
# GIORNALE: Frontiers in endocrinology
#
# ABSTRACT:
# The aim of this study was to characterize large adrenal tumors (LATs), assess the diagnostic accuracy of imaging modalities in detecting malignant LATs, and determine whether further follow-up of seemingly benign LATs is necessary....
#
# LINK: https://pubmed.ncbi.nlm.nih.gov/41788772/

# %%
# Esecuzione della ricerca di immagini e risorse iconografiche
img_resources = image_resource_finder('Adrenal adenoma CT scan Cushing syndrome')
display(img_resources)
# Out:
# 🔍 Ricerca di risorse visive per: Adrenal adenoma CT scan Cushing syndrome
#
# 🔍 Ricerca in corso su PubMed per: Adrenal adenoma CT scan Cushing syndrome AND (image OR figure OR radiology OR CT OR MRI)...
#
#
# &#128161; Suggerimento: Per visualizzare direttamente le immagini mediche, visita:
# https://openi.nlm.nih.gov/gridquery?q=Adrenal+adenoma+CT+scan+Cushing+syndrome
#                                               Titolo  \
# 0           Natural history of large adrenal tumors.
# 1  Endocrine hypertension: the role of imaging in...
# 2  A Novel <i>ARMC5</i> Germline Variant in Sibli...
#
#                            Giornale  \
# 0        Frontiers in endocrinology
# 1  The British journal of radiology
# 2                 JCEM case reports
#
#                                         Link  \
# 0  https://pubmed.ncbi.nlm.nih.gov/41788772/
# 1  https://pubmed.ncbi.nlm.nih.gov/41652884/
# 2  https://pubmed.ncbi.nlm.nih.gov/40895499/
#
# ...

# %% [markdown]
# ### Δ Analisi Comparativa: Risultati Locali vs Letteratura Corrente
#
# | Caratteristica | Casi in df_adrenal_results | Standard Letteratura Attuale |
# | :--- | :--- | :--- |
# | **Eziologia** | Include forme genetiche rare (ARMC5, Carney Complex). | Prevalenza di adenomi sporadici non ereditari. |
# | **Lateralit** | Presenza di forme bilaterali (iperplasia macronodulare). | Solitamente monolaterale (85-90%). |
# | **Secrizione** | Enfasi sulla MACS (Mild Autonomous Cortisol Secretion). | Focus sulla sindrome di Cushing franca o incidentalomi non secernenti. |
# | **Imaging** | Ruolo della TC per tumori di grandi dimensioni (>4cm). | Protocolli wash-out TC per distinguere adenomi da metastasi/carcinomi. |

# %%
# Analisi quantitativa dei termini chiave negli abstract recuperati
import pandas as pd

keywords = ['MACS', 'bilateral', 'genetic', 'Cushing', 'malignant']
analysis = {kw: df_adrenal_results['Abstract'].str.contains(kw, case=False).sum() for kw in keywords}

print("Frequenza termini chiave nei risultati attuali:")
for kw, count in analysis.items():
    print(f"- {kw}: {count} articoli")
# Out:
# Frequenza termini chiave nei risultati attuali:
# - MACS: 1 articoli
# - bilateral: 1 articoli
# - genetic: 2 articoli
# - Cushing: 2 articoli
# - malignant: 1 articoli

# %% [markdown]
# ### ⚖️ Analisi Comparativa: Psicoterapia Dinamica vs CBT per HPD
#
# | Caratteristica | Psicoterapia Psicodinamica | Terapia Cognitivo-Comportamentale (CBT) |
# | :--- | :--- | :--- |
# | **Focus Principale** | Conflitti inconsci, autostima e dinamiche relazionali profonde. | Schemi di pensiero disfunzionali e comportamenti teatrali. |
# | **Obiettivo** | Risoluzione del bisogno di attenzione tramite la comprensione dei vuoti affettivi. | Sviluppo di capacità di problem-solving e riduzione dell'impulsività. |
# | **Tecnica** | Analisi del transfert e delle difese (es. rimozione, dissociazione). | Ristrutturazione cognitiva e training sulle abilità sociali. |
# | **Efficacia** | Considerata molto efficace per modificare la *struttura* della personalità. | Efficace per la gestione *sintomatica* a breve/medio termine. |
# | **Durata** | Solitamente a lungo termine. | Generalmente più breve e focalizzata. |
#
# #### 📌 Sintesi Clinica:
# La letteratura suggerisce che non esiste una superiorità assoluta di un approccio sull'altro. Spesso, la scelta dipende dalla disponibilità del paziente a impegnarsi in un lavoro di introspezione profonda (dinamica) o se preferisce un approccio più strutturato e orientato al compito (CBT). Per l'HPD, la **psicodinamica** rimane storicamente il trattamento d'elezione per affrontare il nucleo dell'identità fragile.

# %% [markdown]
# ### 🎯 Confronto Obiettivi a Lungo Termine: Psicoterapia Dinamica vs CBT
#
# | Obiettivo a Lungo Termine | Psicoterapia Psicodinamica | Terapia Cognitivo-Comportamentale (CBT) |
# | :--- | :--- | :--- |
# | **Integrazione dell'Identità** | Mira a consolidare un senso di sé coeso, riducendo la frammentazione e il vuoto interiore. | Mira a sviluppare un'identità basata su competenze reali e auto-efficacia piuttosto che sulla convalida esterna. |
# | **Regolazione Emotiva** | Ricerca la comprensione delle radici infantili delle emozioni intense per disinnescare i trigger inconsci. | Fornisce strumenti pratici per identificare e modulare l'intensità delle risposte emotive in tempo reale. |
# | **Autonomia Relazionale** | Trasforma il bisogno di attenzione costante in capacità di stabilire legami profondi e reciproci. | Modifica i comportamenti manipolatori o teatrali favorendo una comunicazione assertiva e diretta. |
# | **Meccanismi di Difesa** | Sostituisce difese primitive (rimozione, dissociazione) con strategie di coping mature e consapevoli. | Identifica e corregge i 'bias' cognitivi (es. pensiero tutto-o-nulla) che alimentano l'iper-emotività. |
# | **Stabilità del Risultato** | Punta a un cambiamento strutturale permanente della personalità che previene le ricadute. | Punta al mantenimento delle abilità acquisite attraverso la pratica costante e il monitoraggio dei pensieri. |

# %% [markdown]
# ### 👁️ Trattamento Farmacologico della Cheratocongiuntivite Vernal (VKC)
#
# Il management della VKC deve essere personalizzato in base alla gravità dei sintomi e alla presenza di coinvolgimento corneale (cheratite).
#
# #### 1. Misure Generali e Profilassi
# *   **Evitamento dei Trigger**: Ridurre l'esposizione al sole, al vento e alla polvere.
# *   **Lubrificazione**: Lacrime artificiali senza conservanti per diluire gli allergeni e i mediatori infiammatori.
# *   **Impacchi Freddi**: Utili per dare sollievo immediato dal prurito.
#
# #### 2. Terapia Farmacologica Topica
# | Classe Farmacologica | Esempi | Indicazioni |
# | :--- | :--- | :--- |
# | **Antistaminici/Stabilizzatori Mastociti** | Olopatadina, Ketotifene | Trattamento di prima linea per casi lievi/moderati (mantenimento). |
# | **FANS Topici** | Ketorolac, Diclofenac | Utili per ridurre il dolore e l'iperemia, evitando gli effetti collaterali dei steroidi. |
# | **Corticosteroidi Topici** | Desametasone, Fluorometolone | **Solo per fasi acute (fiammate)**. Richiedono monitoraggio della pressione intraoculare (IOP). |
# | **Immunomodulatori** | **Ciclosporina A**, Tacrolimus | Fondamentali per ridurre la dipendenza dai steroidi nei casi cronici severi. |
#
# #### 3. Casi Gravi e Refrattari
# *   **Iniezione Supratarsale di Steroidi**: Considerata in presenza di papille giganti che causano ulcere corneali a scudo (shield ulcers).
# *   **Chirurgia**: Crioterapia o rimozione chirurgica delle papille giganti se il trattamento medico fallisce.
#
# **⚠️ Nota importante:** L'uso prolungato di steroidi topici nei bambini affetti da VKC è una causa comune di cataratta iatrogena e glaucoma. L'introduzione precoce di risparmiatori di steroidi (Ciclosporina) è spesso raccomandata.

# %% [markdown]
# ### 🩺 Caso Clinico: Adenoma Surrenalico e Sindrome di Cushing
#
# **Inquadramento Diagnostico:**
# *   **Sintomi:** Adiposità centrale, strie rubre, irsutismo, ipertensione, iperglicemia (quadro classico di ipercortisolismo).
# *   **Laboratorio:** Cortisolo urinario $\uparrow\uparrow\uparrow$, ACTH $<5$ pg/mL (soppresso). Questo indica un **Cushing primario (surrenalico)**.
# *   **Imaging:** TC addome positiva per adenoma surrenalico destro.
#
# **Spiegazione della Risposta Corretta:**
# L'intervento d'elezione è la **surrenectomia monolaterale** destra. Poiché l'adenoma ipersecernente ha soppresso l'asse ipofisi-surrene per lungo tempo, il surrene sinistro è atrofico. Nel post-operatorio, la caduta improvvisa dei livelli di cortisolo espone la paziente a un'**insufficienza surrenalica acuta**. È quindi imperativo somministrare **terapia sostitutiva con idrocortisone** fino al ripristino della funzionalità dell'asse (test di stimolo con ACTH dopo alcuni mesi).

# %% [markdown]
# ### 📊 Analisi Comparativa: Linee Guida ESC 2024 vs Protocolli Precedenti (AF)
#
# Le nuove linee guida **ESC 2024** sulla Fibrillazione Atriale (AF) introducono cambiamenti sostanziali rispetto alla versione del 2020, focalizzandosi maggiormente sulla gestione olistica del paziente.
#
# | Ambito | Protocolli Precedenti (2020) | Nuove Linee Guida ESC 2024 |
# | :--- | :--- | :--- |
# | **Approccio Generale** | Percorso **CC to ABC** | Introduzione del percorso **CARE** (Comorbidity management, Avoid stroke, Rate/Rythm control, Evaluation) |
# | **Screening** | Opportunistico nei >65 anni | Raccomandazione forte per lo screening sistematico e l'uso di **dispositivi wearable** |
# | **Anticoagulazione** | Basata esclusivamente su CHA2DS2-VASc | Rivalutazione del rischio emorragico dinamico e focus sulla gestione dei fattori di rischio modificabili |
# | **Controllo del Ritmo** | Ablazione come seconda linea (spesso) | Enfasi sulla **Early Rhythm Control** (ablation first in selezionati pazienti) |
# | **Gestione Comorbilità** | Trattamento delle patologie associate | Gestione aggressiva dell'**obesità** e dell'**ipertensione** come pilastri del trattamento |
#
# #### 🗝️ Punti Chiave dell'Aggiornamento:
# - **Semplificazione**: Il percorso CARE mira a rendere la gestione multidisciplinare più fluida.
# - **Prevenzione**: Maggiore enfasi sulla modifica dello stile di vita per ridurre il carico (burden) della FA.
# - **Paziente al Centro**: Decisioni condivise (Shared Decision Making) potenziate per migliorare l'aderenza alla terapia.

# %% [markdown]
# ### 💓 Evoluzione del Controllo del Ritmo: ESC 2020 vs ESC 2024
#
# Il controllo del ritmo ha subito uno dei cambiamenti più radicali nell'ultimo aggiornamento, passando da una gestione focalizzata sui sintomi a una strategia di preservazione del substrato atriale.
#
# | Caratteristica | Linee Guida ESC 2020 | Nuove Linee Guida ESC 2024 |
# | :--- | :--- | :--- |
# | **Obiettivo Primario** | Miglioramento della qualità della vita (sintomi). | Prevenzione del rimodellamento atriale e degli eventi avversi (Early Rhythm Control). |
# | **Timing dell'intervento** | Spesso ritardato fino al fallimento della terapia medica. | **Intervento precoce** raccomandato entro pochi mesi dalla diagnosi. |
# | **Ablazione Transcatetere** | Seconda linea dopo fallimento farmaci antiaritmici (AAD). | **Classe I (Prima Linea)** per pazienti con FA parossistica o persistente senza fattori di rischio maggiori. |
# | **FA e Scompenso (HFrEF)** | Raccomandata se sospetta tachicardiomiopatia. | **Classe I**: L'ablazione è indicata per ridurre mortalità e ospedalizzazioni. |
# | **Scelta dei Farmaci** | Basata principalmente sulla sicurezza/profilo di rischio. | Maggiore cautela nell'uso a lungo termine; i farmaci sono visti spesso come 'ponte' all'ablazione. |
#
# #### 🚀 Focus: Perché "Early Rhythm Control"?
# Le evidenze degli ultimi anni (come lo studio EAST-AFNET 4) hanno dimostrato che stabilizzare il ritmo sinusale precocemente riduce significativamente il rischio di morte cardiovascolare e ictus, indipendentemente dalla gravità dei sintomi.
#
# **In sintesi:** Nel 2024, l'ablazione non è più l'ultima spiaggia, ma uno strumento preventivo cardine per evitare che la FA diventi permanente.

# %% [markdown]
# ### 🖼️ Ricerca Immagini Mediche e Iconografia
#
# Poiché la visualizzazione diretta di immagini richiede l'accesso a repository specifici, utilizziamo lo script seguente per identificare articoli Open Access che includono figure, grafici e immagini radiologiche (utilizzando metadati PubMed o API Open-i).

# %%
def image_resource_finder(query):
    # Cerchiamo articoli che contengano specificamente immagini o siano 'Review' con materiale iconografico
    image_query = f'{query} AND (image OR figure OR radiology OR CT OR MRI)'
    print(f'🔍 Ricerca di risorse visive per: {query}\n')

    # Riutilizziamo l'agente PubMed esistente per trovare link con figure
    df_images = medical_search_agent(image_query, max_results=3)

    # Aggiungiamo un suggerimento per Open-i
    print('\n💡 Suggerimento: Per visualizzare direttamente le immagini, puoi visitare:')
    print(f'https://openi.nlm.nih.gov/gridquery?q={query.replace(" ", "+")}')

    return df_images

# Esempio per Sarcoidosi (Pattern Radiologici)
img_results = image_resource_finder('Sarcoidosis pulmonary patterns')
display(img_results)
# Out:
# 🔍 Ricerca di risorse visive per: Sarcoidosis pulmonary patterns
#
# 🔍 Ricerca in corso su PubMed per: Sarcoidosis pulmonary patterns AND (image OR figure OR radiology OR CT OR MRI)...
#
#
# 💡 Suggerimento: Per visualizzare direttamente le immagini, puoi visitare:
# https://openi.nlm.nih.gov/gridquery?q=Sarcoidosis+pulmonary+patterns
#                                               Titolo  \
# 0  Clinical and Imaging Abnormalities Associated ...
# 1  The double threat: imaging manifestations of t...
# 2  [Extrapulmonary sarcoidosis with multiorgan in...
#
#                                             Giornale  \
# 0          Journal of the American Heart Association
# 1  The international journal of cardiovascular im...
# 2               Innere Medizin (Heidelberg, Germany)
#
#                                         Link  \
# 0  https://pubmed.ncbi.nlm.nih.gov/42003667/
# 1  https://pubmed.ncbi.nlm.nih.gov/41933232/
# 2  https://pubmed.ncbi.nlm.nih.gov/41912901/
#
# ...
