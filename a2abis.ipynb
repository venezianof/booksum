# %% [markdown]
# <a href="https://colab.research.google.com/github/venezianof/booksum/blob/main/a2abis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python __main__.py
# Out:
# Traceback (most recent call last):
#   File "/content/a2a-samples/samples/python/agents/helloworld/__main__.py", line 3, in <module>
#     from a2a.server.apps import A2AStarletteApplication
# ModuleNotFoundError: No module named 'a2a'

# %%
# !uv run -v .
# Out:
# DEBUG uv 0.9.22
# DEBUG Acquired shared lock for `/root/.cache/uv`
# DEBUG Found project root: `/content/a2a-samples/samples/python/agents/helloworld`
# DEBUG Found workspace root `/content/a2a-samples/samples/python`, but project is not included
# DEBUG No workspace root found, using project root
# DEBUG Discovered project `helloworld` at: /content/a2a-samples/samples/python/agents/helloworld
# DEBUG Acquired exclusive lock for `/content/a2a-samples/samples/python/agents/helloworld`
# DEBUG No Python version file found in workspace: /content/a2a-samples/samples/python/agents/helloworld
# DEBUG Using Python request `>=3.10` from `requires-python` metadata
# DEBUG Checking for Python environment at: `.venv`
# DEBUG The project environment's Python version satisfies the request: `Python >=3.10`
# DEBUG Released lock at `/tmp/uv-39a3643829049cff.lock`
# DEBUG Acquired exclusive lock for `.venv`
# DEBUG Using request timeout of 30s
# ...

# %%
# %cd /content/a2a-samples/samples/python/agents/helloworld
# Out:
# /content/a2a-samples/samples/python/agents/helloworld

# %%
# !ls -la
# Out:
# total 220
# drwxr-xr-x  5 root root   4096 Jan  6 12:07 .
# drwxr-xr-x 31 root root   4096 Jan  6 12:07 ..
# -rw-r--r--  1 root root   1179 Jan  6 12:07 agent_executor.py
# -rw-r--r--  1 root root   1305 Jan  6 12:07 Containerfile
# -rw-r--r--  1 root root      0 Jan  6 12:07 __init__.py
# -rw-r--r--  1 root root   2679 Jan  6 12:07 __main__.py
# drwxr-xr-x  2 root root   4096 Jan  6 12:07 __pycache__
# -rw-r--r--  1 root root    582 Jan  6 12:07 pyproject.toml
# -rw-r--r--  1 root root   1931 Jan  6 12:07 README.md
# -rw-r--r--  1 root root   5057 Jan  6 12:07 test_client.py
# -rw-r--r--  1 root root 175568 Jan  6 12:07 uv.lock
# drwxr-xr-x  4 root root   4096 Jan  6 12:07 .venv
# drwxr-xr-x  2 root root   4096 Jan  6 12:07 .vscode

# %%
# !cat pyproject.toml 2>/dev/null || echo "pyproject.toml non trovato"
# Out:
# [project]
# name = "helloworld"
# version = "0.1.0"
# description = "HelloWorld agent example that only returns Messages"
# readme = "README.md"
# requires-python = ">=3.10"
# dependencies = [
#     "a2a-sdk>=0.3.0",
#     "click>=8.1.8",
#     "dotenv>=0.9.9",
#     "httpx>=0.28.1",
#     "langchain-google-genai>=2.1.4",
#     "langgraph>=0.4.1",
#     "pydantic>=2.11.4",
#     "python-dotenv>=1.1.0",
#     "sse-starlette>=2.3.5",
#     "starlette>=0.46.2",
#     "uvicorn>=0.34.2",
# ]
#
# [tool.hatch.build.targets.wheel]
# packages = ["."]
#
# [build-system]
# requires = ["hatchling"]
# build-backend = "hatchling.build"

# %%
# !git clone https://github.com/a2aproject/a2a-samples.git
# Out:
# Cloning into 'a2a-samples'...
# remote: Enumerating objects: 5196, done.
# remote: Counting objects: 100% (215/215), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 5196 (delta 127), reused 77 (delta 75), pack-reused 4981 (from 3)
# Receiving objects: 100% (5196/5196), 27.91 MiB | 26.08 MiB/s, done.
# Resolving deltas: 100% (2828/2828), done.

# %%
# %cd a2a-samples/samples/python/agents/helloworld
# Out:
# /content/a2a-samples/samples/python/agents/helloworld

# %%
# !pip install uv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 71.7 MB/s eta 0:00:00
# ...

# %%
# !uv run .
# Out:
# Using CPython 3.12.12 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Installed 55 packages in 100ms
# INFO:     Started server process [1361]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:9999 (Press CTRL+C to quit)
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [1361]
