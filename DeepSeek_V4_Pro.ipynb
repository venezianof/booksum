# %% [markdown]
# <a href="https://colab.research.google.com/github/venezianof/booksum/blob/main/DeepSeek_V4_Pro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers

# %%
# !pip install -q openai bibtexparser
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for bibtexparser (setup.py) ... done

# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/deepseek-ai/DeepSeek-V4-Pro
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/deepseek-ai/DeepSeek-V4-Pro)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="deepseek-ai/DeepSeek-V4-Pro")
messages = [
    {"role": "user", "content": "Who are you?"},
]
pipe(messages)

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("deepseek-ai/DeepSeek-V4-Pro")
model = AutoModelForCausalLM.from_pretrained("deepseek-ai/DeepSeek-V4-Pro", device_map="auto")

# %% [markdown]
# ## Remote Inference via Inference Providers
# Ensure you have a valid **HF_TOKEN** set in your environment. You can get your token from [your settings page](https://huggingface.co/settings/tokens). Note: running this may incur charges above the free tier.
# The following Python example shows how to run the model remotely on HF Inference Providers, automatically selecting an available inference provider for you.
# For more information on how to use the Inference Providers, please refer to our [documentation and guides](https://huggingface.co/docs/inference-providers/en/index).

# %%
import os
os.environ['HF_TOKEN'] = 'YOUR_TOKEN_HERE'

# %%
import os
from openai import OpenAI
try:
    from google.colab import userdata
    api_key = userdata.get('HF_TOKEN')
except Exception:
    api_key = os.environ.get("HF_TOKEN", "")

if not api_key or api_key == "YOUR_TOKEN_HERE":
    print("ATTENZIONE: Inserisci il tuo HF_TOKEN nei segreti di Colab (icona chiave) e abilita l'accesso.")
else:
    # Rimuove eventuali spazi bianchi o caratteri invisibili (come \xa0)
    api_key = api_key.strip()
    client = OpenAI(
        base_url="https://router.huggingface.co/v1",
        api_key=api_key,
    )
    print("Client configurato correttamente con token pulito rilevato.")
# Out:
# Client configurato correttamente con token pulito rilevato.

# %% [markdown]
# ### Agente Ricerca Medica Profonda
# Configurazione dell'agente per l'analisi di bibliografia Medline, abstract e linee guida terapeutiche.

# %%
def get_medical_research(topic):
    system_prompt = """Sei un assistente di ricerca medica avanzata.
    Il tuo compito è fornire:
    1. Bibliografia dettagliata (stile Medline/PubMed).
    2. Abstract riassuntivi delle ultime terapie.
    3. Schemi terapeutici e linee guida ufficiali.
    4. Descrizione di immagini/schemi diagnostici.
    Usa un linguaggio tecnico e preciso."""

    try:
        response = client.chat.completions.create(
            model="deepseek-ai/DeepSeek-V4-Pro",
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": f"Esegui una ricerca profonda su: {topic}"}
            ],
            temperature=0.3
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Errore durante la ricerca: {str(e)}"

# %%
# Eseguiamo una ricerca approfondita su un tema oncologico moderno
tema_ricerca = "Immunoterapia e inibitori dei checkpoint nel tumore del polmone non a piccole cellule (NSCLC)"
risultato = get_medical_research(tema_ricerca)

print(f"### Risultati Ricerca Medica: {tema_ricerca} ###\n")
print(risultato)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1497/4061931589.py in <cell line: 0>()
#       1 # Eseguiamo una ricerca approfondita su un tema oncologico moderno
#       2 tema_ricerca = "Immunoterapia e inibitori dei checkpoint nel tumore del polmone non a piccole cellule (NSCLC)"
# ----> 3 risultato = get_medical_research(tema_ricerca)
#       4
#       5 print(f"### Risultati Ricerca Medica: {tema_ricerca} ###\n")
#
# NameError: name 'get_medical_research' is not defined

# %%
# Eseguiamo una ricerca approfondita su un tema oncologico moderno
tema_ricerca = "Immunoterapia e inibitori dei checkpoint nel tumore del polmone non a piccole cellule (NSCLC)"
risultato = get_medical_research(tema_ricerca)

print(f"### Risultati Ricerca Medica: {tema_ricerca} ###\n")
print(risultato)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1497/4061931589.py in <cell line: 0>()
#       1 # Eseguiamo una ricerca approfondita su un tema oncologico moderno
#       2 tema_ricerca = "Immunoterapia e inibitori dei checkpoint nel tumore del polmone non a piccole cellule (NSCLC)"
# ----> 3 risultato = get_medical_research(tema_ricerca)
#       4
#       5 print(f"### Risultati Ricerca Medica: {tema_ricerca} ###\n")
#
# NameError: name 'get_medical_research' is not defined

# %% [markdown]
# ### Analisi Caso Clinico: Otalgia e Fluttuazione del Condotto
# Ricerca su diagnosi differenziale e approccio terapeutico (Incisione/Drenaggio vs Antibiotici).

# %%
caso_clinico = """
Uomo 38 anni, otalgia destra intensa, gonfiore eritematoso focale nel condotto cartilagineo con punto di fluttuazione. Timpano integro. Diagnosi sospetta: Furuncolosi del condotto uditivo esterno.
Quesito: Approccio terapeutico indicato (Incisione e drenaggio vs Antibiotici orali anti-stafilococcici vs Gocce topiche vs Antifungini).
"""

# Esecuzione della ricerca con l'agente medico
print(f"### Analisi Agente Ricerca Medica Profonda ###\n")
risultato = get_medical_research(caso_clinico)
print(risultato)
# Out:
# ### Analisi Agente Ricerca Medica Profonda ###
#
# **Approccio terapeutico alla furuncolosi del condotto uditivo esterno con punto di fluttuazione**
#
# La furuncolosi del condotto uditivo esterno (CAE) è un’infezione acuta, localizzata, di un follicolo pilifero nel terzo laterale (cartilagineo) del condotto, quasi sempre sostenuta da *Staphylococcus aureus*. Il quadro clinico descritto – otalgia intensa, tumefazione eritematosa focale con punto di fluttuazione, timpano integro – configura un ascesso conclamato. In questa fase, la scelta terapeutica si basa su tre pilastri: drenaggio chirurgico, antibioticoterapia sistemica mirata e gestione topica adiuvante. Gli antifungini non hanno alcun ruolo, poiché l’eziologia è batterica.
#
# ---
#
# ### 1. Bibliografia dettagliata (stile Medline/PubMed)
#
# 1. Rosenfeld RM, Schwartz SR, Cannon CR, et al. Clinical practice guideline: acute otitis externa. *Otolaryngol Head Neck Surg*. 2014;150(1 Suppl):S1-S24. doi:10.1177/0194599813517083
#    *Linea guida di riferimento dell’American Academy of Otolaryngology–Head and Neck Surgery (AAO-HNS) per l’otite esterna acuta, che include la gestione della furuncolosi.*
#
# 2. Kaushik V, Malik T, Saeed SR. Interventions for acute otitis externa. *Cochrane Database Syst Rev*. 2010;(1):CD004740. doi:10.1002/14651858.CD004740.pub2
#    *Revisione sistematica sugli interventi per l’otite esterna acuta; analizza efficacia di antibiotici topici, sistemici e corticosteroidi.*
#
# 3. Roland PS, Stroman DW. Microbiology of acute otitis externa. *Laryngoscope*. 2002;112(7 Pt 1):1166-1177. doi:10.1097/00005537-200207000-00005
#    *Studio microbiologico che conferma la predominanza di S. aureus e Pseudomonas aeruginosa nell’otite esterna, con focus sulla flora del condotto.*
#
# 4. Osguthorpe JD, Nielsen DR. Otitis externa: review and clinical update. *Am Fam Physician*. 2006;74(9):1510-1516.
#    *Revisione clinica per il medico di famiglia, con algoritmo terapeutico per le diverse forme di otite esterna, inclusa la furuncolosi.*
#
# 5. Hajioff D, MacKeith S. Otitis externa. *BMJ Clin Evid*. 2015;2015:0510.
#    *Sintesi delle evidenze cliniche, con raccomandazioni pratiche per il trattamento.*
#
# 6. Sander R. Otitis externa: a practical guide to treatment and prevention. *Am Fam Physician*. 2001;63(5):927-936.
#    *Guida pratica che descrive l’incisione e drenaggio come cardine della furuncolosi ascessualizzata.*
#
# 7. Clark MPA, Westerberg BD, Mitchell TE. Development and validation of a clinical prediction rule for acute otitis externa. *J Otolaryngol Head Neck Surg*. 2008;37(5):685-690.
#    *Studio sulla diagnosi clinica, utile per differenziare la furuncolosi da altre forme di otite esterna.*
#
# ---
#
# ### 2. Abstract riassuntivi delle ultime terapie
#
# - **Incisione e drenaggio (I&D)**
#   In presenza di fluttuazione, l’I&D rappresenta il trattamento risolutivo. L’evacuazione del pus riduce immediatamente la pressione endoluminale, allevia il dolore e accelera la guarigione. La procedura viene eseguita in anestesia locale, con una piccola incisione lineare parallela all’asse del condotto, seguita da irrigazione con soluzione fisiologica. Dopo il drenaggio, si applica una medicazione con garza iodoformica o un tampone imbevuto di antibiotico topico, da rimuovere dopo 24-48 ore. Le linee guida AAO-HNS (2014) raccomandano l’I&D per tutti gli ascessi fluttuanti del CAE.
#
# - **Antibiotici orali anti-stafilococcici**
#   Gli antibiotici sistemici sono indicati quando l’infezione si estende oltre il follicolo (cellulite periauricolare, linfoadenite, febbre) o in pazienti immunocompromessi/diabetici. In caso di furuncolosi semplice con fluttuazione ma senza segni sistemici, l’I&D da sola può essere sufficiente. Tuttavia, molti clinici associano una copertura anti-stafilococcica orale (es. cefalexina, dicloxacillina, clindamicina in caso di allergia alla penicillina) per 5-7 giorni, soprattutto se il drenaggio è incompleto o vi è rischio di recidiva. La scelta deve tenere conto della prevalenza locale di MRSA; in comunità con alta incidenza, si possono considerare trimetoprim-sulfametossazolo o doxiciclina.
#
# - **Gocce topiche**
#   Le gocce auricolari antibiotiche (es. ciprofloxacina, ofloxacina, combinazioni con corticosteroidi) sono il cardine dell’otite esterna diffusa, ma nella furuncolosi ascessualizzata la penetrazione del farmaco è ostacolata dalla raccolta purulenta e dall’edema. Pertanto, le gocce da sole non sono sufficienti a risolvere un ascesso fluttuante. Possono essere utilizzate come adiuvanti dopo I&D per mantenere la pervietà del condotto e prevenire sovrainfezioni. Le gocce a base di aminoglicosidi (neomicina) sono sconsigliate se non si ha certezza dell’integrità timpanica, ma in questo caso il timpano è integro, quindi potrebbero essere opzioni, sebbene le formulazioni con fluorochinolonici siano preferibili per il profilo di sicurezza.
#
# - **Antifungini**
#   Non hanno alcuna indicazione nella furuncolosi batterica. L’otomycosi (infezione fungina del CAE) si presenta tipicamente con prurito, desquamazione e secrezioni biancastre/nerastre, senza il dolore intenso e la tumefazione focale della furuncolosi. L’uso empirico di antifungini sarebbe inappropriato e ritarderebbe il trattamento corretto.
#
# ---
#
# ### 3. Schemi terapeutici e linee guida ufficiali
#
# **Algoritmo decisionale per furuncolosi del CAE con fluttuazione (basato su AAO-HNS 2014 e revisioni successive):**
#
# 1. **Valutazione clinica**
#    - Confermare l’integrità timpanica (otoscopia).
#    - Escludere segni di estensione: cellulite del padiglione, linfoadenopatia preauricolare, febbre, trisma (possibile otite esterna maligna nei diabetici/immunocompromessi).
#    - Identificare il punto di fluttuazione.
#
# 2. **Trattamento di prima linea: Incisione e drenaggio**
#    - Anestesia locale con lidocaina 1% senza adrenalina infiltrata nella cute del condotto (o spray anestetico).
#    - Incisione con bisturi a lama piccola (n. 11 o 15) orientata lungo l’asse del condotto, sulla sommità della fluttuazione.
#    - Drenaggio delicato del pus, eventuale prelievo per coltura se recidivante o sospetto MRSA.
#    - Irrigazione con soluzione fisiologica tiepida.
#    - Inserimento di una striscia di garza iodoformica o di un tampone di cotone imbevuto di antibiotico topico (es. ciprofloxacina) per mantenere aperto il drenaggio e prevenire la riadesione dei margini. Rimozione dopo 24-48 ore.
#
# 3. **Terapia farmacologica adiuvante**
#    - **Antibiotico topico post-drenaggio**: gocce di ciprofloxacina 0.3% + desametasone 0.1% (es. Ciprodex), 4 gocce 2 volte/die per 7 giorni, per ridurre l’edema residuo e prevenire infezioni secondarie.
#    - **Antibiotico sistemico**: da riservare ai casi con:
#      - Cellulite periauricolare o febbre.
#      - Diabete mellito, immunodeficienza.
#      - Recidive frequenti.
#      - Impossibilità a eseguire un drenaggio adeguato.
#      Schema consigliato:
#      - Cefalexina 500 mg per os ogni 6 ore per 7 giorni (prima scelta).
#      - In alternativa: dicloxacillina 500 mg ogni 6 ore, o clindamicina 300 mg ogni 8 ore (se allergia beta-lattamici).
#      - In aree ad alta prevalenza di MRSA: trimetoprim-sulfametossazolo 800/160 mg ogni 12 ore o doxiciclina 100 mg ogni 12 ore per 7 giorni.
#    - **Analgesia**: FANS o paracetamolo secondo necessità.
#
# 4. **Follow-up**
#    - Controllo a 48-72 ore per rimuovere la medicazione e verificare la risoluzione.
#    - Se non migliora, rivalutare la diagnosi (es. cisti epidermoide infetta, otite esterna maligna) e richiedere coltura con antibiogramma.
#
# **Cosa evitare:**
# - Non usare gocce topiche come unico trattamento in presenza di fluttuazione.
# - Non somministrare antifungini.
# - Non eseguire incisioni profonde o perpendicolari che potrebbero danneggiare la cartilagine.
# - Non utilizzare aminoglicosidi topici se non si ha la certezza dell’integrità timpanica (qui il timpano è integro, ma i fluorochinolonici sono comunque preferibili per il minor rischio di ototossicità in caso di perforazione misconosciuta).
#
# ---
#
# ### 4. Descrizione di immagini/schemi diagnostici
#
# **Quadro otoscopico tipico della furuncolosi ascessualizzata del CAE:**
#
# - **Condotto uditivo esterno**: nel terzo laterale (cartilagineo) si osserva una tumefazione rotondeggiante, eritematosa, a superficie liscia e tesa, che sporge nel lume riducendone il calibro. Al centro della tumefazione è visibile un’area giallastra o biancastra (punto di fluttuazione) corrispondente alla raccolta purulenta sottostante. La cute circostante può essere iperemica e dolente alla trazione del padiglione o alla pressione sul trago (segno del trago positivo).
# - **Timpano**: normale, di colore grigio perlaceo, con riflesso luminoso conservato, mobilità alla manovra di Valsalva (se eseguibile). L’integrità della membrana timpanica esclude un’otite media acuta complicata.
# - **Diagnosi differenziale**: a differenza dell’otite esterna diffusa, dove l’edema e l’eritema coinvolgono l’intero condotto, qui la lesione è focale. L’assenza di secrezioni caseose o di ife all’esame microscopico esclude l’otomycosi. La presenza di fluttuazione distingue l’ascesso dalla semplice follicolite.
#
# **Schema procedurale per l’incisione e drenaggio (descrizione testuale):**
#
# 1. Posizionare il paziente supino con la testa ruotata controlateralmente.
# 2. Illuminare il condotto con otoscopio o microscopio operatorio.
# 3. Infiltrare 0.5-1 ml di lidocaina 1% senza adrenalina con ago sottile (27 G) nella cute sovrastante l’ascesso, previa disinfezione.
# 4. Con bisturi monouso a lama appuntita, praticare un’incisione di 2-3 mm parallela all’asse del condotto, sulla sommità della fluttuazione.
# 5. Esercitare una leggera pressione con un tampone di cotone per favorire la fuoriuscita del pus.
# 6. Irrigare abbondantemente con soluzione fisiologica.
# 7. Inserire una striscia di garza iodoformica (o un tampone imbevuto di antibiotico) nel sito di incisione, lasciando l’estremità sporgente per facilitare la rimozione.
# 8. Applicare una medicazione esterna leggera.
#
# ---
#
# **Conclusione:** In un uomo di 38 anni con furuncolosi del CAE e punto di fluttuazione, l’approccio terapeutico indicato è l’**incisione e drenaggio immediato**, associato a **gocce topiche antibiotico-steroidee post-procedura**. L’**antibiotico orale anti-stafilococcico** va aggiunto solo in presenza di segni di diffusione o fattori di rischio. Gli **antifungini** non sono indicati. Tale strategia è supportata dalle linee guida internazionali e garantisce rapida risoluzione del dolore e prevenzione delle recidive.

# %% [markdown]
# ### Riassunto: Procedura di Incisione e Drenaggio (Furuncolosi CAE)
#
# 1. **Preparazione**: Paziente supino, testa ruotata e illuminazione ottimale (otoscopio o microscopio).
# 2. **Anestesia**: Infiltrazione locale con lidocaina 1% (senza adrenalina) usando un ago sottile (27 G).
# 3. **Incisione**: Taglio di 2-3 mm con lama appuntita sulla sommità del punto di fluttuazione, parallelamente all'asse del condotto.
# 4. **Evacuazione**: Pressione delicata per rimuovere il materiale purulento e lavaggio con soluzione fisiologica.
# 5. **Zaffaggio**: Inserimento di una striscia di garza iodoformica o tampone antibiotico nel sito chirurgico.
# 6. **Follow-up**: Rimozione del drenaggio dopo 24-48 ore e inizio di terapia topica antibiotico-steroidea.

# %% [markdown]
# ### Farmacoterapia Consigliata e Posologie
# Tabella riassuntiva basata sulla ricerca dell'agente DeepSeek per il trattamento della furuncolosi del CAE.

# %%
prompt_farmaci = """
Crea una tabella riassuntiva dei farmaci consigliati per la furuncolosi del condotto uditivo esterno (S. aureus).
Includi:
1. Antibiotici orali (es. Flucloxacillina, Cefalexina) con posologia per adulti.
2. Gocce topiche (antibiotico + steroide).
3. Analgesici per il controllo del dolore.
4. Nota su quando iniziare la terapia sistemica.
Formato: Tabella Markdown.
"""

risultato_farmaci = get_medical_research(prompt_farmaci)
print(risultato_farmaci)
# Out:
# ## Furuncolosi del condotto uditivo esterno (S. aureus): Tabella riassuntiva dei farmaci e approfondimenti
#
# La furuncolosi del condotto uditivo esterno è un’infezione piogenica localizzata a un follicolo pilifero del terzo laterale del meato, sostenuta quasi esclusivamente da *Staphylococcus aureus*. Si presenta come un nodulo dolente, eritematoso, che può evolvere in ascesso fluttuante. Il trattamento si basa su misure locali (impacchi caldi, incisione e drenaggio se fluttuante), terapia antibiotica topica e, nei casi moderati-gravi, sistemica, oltre a un adeguato controllo del dolore.
#
# ### Tabella riassuntiva dei farmaci consigliati
#
# | Categoria | Farmaco (principio attivo) | Posologia adulti | Note |
# |-----------|----------------------------|------------------|------|
# | **Antibiotici orali** (prima scelta) | Flucloxacillina | 500 mg ogni 6 ore per 7 giorni | Penicillina penicillinasi-resistente. Non disponibile in USA (sostituire con dicloxacillina 500 mg q6h). Assumere a stomaco vuoto. |
# | | Cefalexina | 500 mg ogni 6–8 ore per 7 giorni | Cefalosporina di I generazione. Alternativa in caso di allergia non grave alla penicillina (cross-reattività <10%). |
# | **Antibiotici orali** (allergia alla penicillina) | Clindamicina | 300–450 mg ogni 6 ore per 7 giorni | Efficace contro S. aureus meticillino-sensibile (MSSA). Rischio di colite da *C. difficile*. |
# | | Doxiciclina | 100 mg ogni 12 ore per 7 giorni | Buona penetrazione tissutale. Utile se sospetta MRSA di comunità. |
# | **Gocce topiche** (antibiotico + steroide) | Ciprofloxacina 0,3% + idrocortisone 1% (es. Cipro HC) | 3–4 gocce ogni 8–12 ore per 7 giorni | Fluoro‑chinolonico + steroide. Non ototossico. Copre *Pseudomonas* e *S. aureus*. |
# | | Neomicina + polimixina B + idrocortisone (es. Cortisporin) | 3–4 gocce ogni 6–8 ore per 7 giorni | Attenzione: neomicina può causare sensibilizzazione cutanea (dermatite da contatto). Evitare se sospetta perforazione timpanica. |
# | | Gentamicina 0,3% + betametasone 0,1% (es. Garasone) | 3–4 gocce ogni 8 ore per 7 giorni | Aminoglicoside + steroide. Potenzialmente ototossico se la membrana timpanica non è integra. |
# | **Analgesici** | Ibuprofene | 400–600 mg ogni 6–8 ore (max 2400 mg/die) | FANS. Azione antinfiammatoria e analgesica. |
# | | Paracetamolo (acetaminofene) | 500–1000 mg ogni 6 ore (max 3000 mg/die) | Analgesico puro. Utile in associazione o se controindicazioni ai FANS. |
# | | Codeina + paracetamolo (es. Co‑efferalgan) | 30/500 mg ogni 6 ore | Oppioide debole. Solo per dolore intenso non controllato dai precedenti, per brevi periodi. |
#
# ### Nota: quando iniziare la terapia sistemica
#
# La terapia antibiotica orale è indicata in presenza di uno o più dei seguenti criteri:
# - Cellulite periauricolare o estensione dell’infezione oltre il condotto uditivo.
# - Febbre o segni sistemici.
# - Immunocompromissione (diabete mellito, HIV, terapia immunosoppressiva).
# - Fallimento della terapia topica dopo 48–72 ore.
# - Ascesso di grandi dimensioni (>1 cm) o fluttuante che richiede drenaggio.
# - Dolore severo non responsivo ai soli analgesici.
#
# In tutti gli altri casi, la furuncolosi lieve-moderata può essere gestita con impacchi caldi, gocce topiche e analgesici, riservando l’antibiotico sistemico ai pazienti a rischio o con malattia più aggressiva.
#
# ---
#
# ## Bibliografia (stile Medline/PubMed)
#
# 1. Rosenfeld RM, Schwartz SR, Cannon CR, et al. Clinical practice guideline: acute otitis externa. *Otolaryngol Head Neck Surg*. 2014;150(1 Suppl):S1-S24. doi:10.1177/0194599813517083.
# 2. Kaushik V, Malik T, Saeed SR. Interventions for acute otitis externa. *Cochrane Database Syst Rev*. 2010;(1):CD004740. doi:10.1002/14651858.CD004740.pub2.
# 3. NICE. Boils and carbuncles: antimicrobial prescribing. NICE guideline [NG109]. Published: 22 February 2018. Available at: https://www.nice.org.uk/guidance/ng109.
# 4. Osguthorpe JD, Nielsen DR. Otitis externa: review and clinical update. *Am Fam Physician*. 2006;74(9):1510-1516.
# 5. Hajioff D, MacKeith S. Otitis externa. *BMJ Clin Evid*. 2015;2015:0510.
# 6. Roland PS, Stroman DW. Microbiology of acute otitis externa. *Laryngoscope*. 2002;112(7 Pt 1):1166-1177. doi:10.1097/00005537-200207000-00005.
#
# ## Abstract riassuntivi delle ultime terapie
#
# La gestione moderna della furuncolosi del condotto uditivo esterno enfatizza un approccio stratificato. Le forme lievi, senza segni di diffusione, rispondono bene alle sole gocce topiche contenenti un antibiotico ad ampio spettro (ciprofloxacina) e uno steroide, che riduce rapidamente l’infiammazione e il dolore. L’aggiunta di un antibiotico sistemico è riservata ai casi complicati, come documentato dalla linea guida AAO-HNS 2014, che raccomanda la terapia orale solo in presenza di cellulite estesa, immunodepressione o fallimento topico. La scelta dell’antibiotico orale deve coprire *S. aureus* meticillino-sensibile (MSSA); flucloxacillina e cefalexina rappresentano i capisaldi, mentre clindamicina e doxiciclina sono opzioni in caso di allergia o sospetta MRSA di comunità. L’incisione e il drenaggio, quando è presente una raccolta fluttuante, accelerano la guarigione e riducono la necessità di antibiotici prolungati. Il controllo del dolore si basa su FANS e paracetamolo, con oppioidi deboli solo per brevi periodi nei casi più severi.
#
# ## Schemi terapeutici e linee guida ufficiali
#
# **Linea guida AAO-HNS per l’otite esterna acuta (2014)**
# - Raccomanda gocce topiche come terapia di prima linea per tutte le forme non complicate.
# - L’antibiotico sistemico è indicato solo se vi è estensione oltre il condotto (cellulite del padiglione, linfoadenopatia satellite) o in pazienti immunocompromessi.
# - L’uso di steroidi topici è fortemente raccomandato per ridurre l’edema e il dolore.
#
# **Linea guida NICE (NG109) su foruncoli e carbonchi (2018)**
# - Per il foruncolo semplice, drenaggio spontaneo o incisione e drenaggio, senza antibiotici sistemici.
# - Antibiotico orale (flucloxacillina 500 mg qds per 7 giorni) se: cellulite circostante, segni sistemici, localizzazione a rischio (es. orecchio), immunocompromissione.
# - In caso di allergia alla penicillina: claritromicina o doxiciclina.
#
# **Schema pratico integrato**
# 1. **Valutazione**: esame otoscopico per confermare la localizzazione nel terzo esterno, escludere perforazione timpanica.
# 2. **Terapia locale**: impacchi caldi 3–4 volte/die + gocce topiche (ciprofloxacina/idrocortisone) per 7 giorni.
# 3. **Drenaggio**: se fluttuante, incisione con ago o bisturi in anestesia locale.
# 4. **Terapia sistemica**: se presenti i criteri sopra elencati, iniziare flucloxacillina 500 mg q6h (o cefalexina) per 7 giorni.
# 5. **Controllo del dolore**: ibuprofene 400 mg q6h al bisogno; se insufficiente, aggiungere paracetamolo 1000 mg q6h.
# 6. **Follow-up**: rivalutazione a 48–72 ore; se non migliora, considerare coltura del pus e modifica della terapia.
#
# ## Descrizione di immagini/schemi diagnostici
#
# L’otoscopia mostra una tumefazione eritematosa, dolente, localizzata nel terzo laterale del condotto uditivo esterno, spesso in corrispondenza di un follicolo pilifero. Nelle fasi iniziali si apprezza un nodulo duro, iperemico, senza punto di fluttuazione. Con la suppurazione compare una pustola centrale giallastra (punto di raccolta purulenta) che può rompersi spontaneamente. Il resto del condotto e la membrana timpanica appaiono normali, a meno che l’edema non impedisca la visualizzazione. La palpazione del trago e la trazione del padiglione auricolare evocano dolore intenso (segno del trago positivo). Non sono necessari esami di imaging; l’ecografia può essere utile in casi dubbi per confermare la presenza di una raccolta ascessuale. La diagnosi differenziale include l’otite esterna diffusa, l’herpes zoster oticus (sindrome di Ramsay Hunt) e, raramente, una neoplasia infetta.

# %% [markdown]
# ### Confronto Linee Guida: Gestione Recidive (AAO-HNS vs NICE)
# Analisi comparativa sulle strategie di prevenzione e trattamento delle infezioni ricorrenti da S. aureus nel CAE.

# %%
prompt_confronto = """
Esegui un confronto dettagliato tra le linee guida AAO-HNS (USA) e NICE (UK) per la gestione delle recidive di furuncolosi del condotto uditivo esterno.
Focus su:
1. Protocolli di decolonizzazione per S. aureus (es. mupirocina nasale, lavaggi con clorexidina).
2. Differenze nell'uso profilattico di antibiotici o acidificanti.
3. Criteri per l'invio allo specialista o ulteriori indagini (es. screening diabete).
Formato: Analisi comparativa strutturata.
"""

risultato_confronto = get_medical_research(prompt_confronto)
print(risultato_confronto)
# Out:
# # Analisi comparativa strutturata: Linee guida AAO-HNS (USA) vs. NICE (UK) per la gestione delle recidive di furuncolosi del condotto uditivo esterno
#
# La furuncolosi recidivante del condotto uditivo esterno (otite esterna localizzata recidivante) è prevalentemente sostenuta da *Staphylococcus aureus*. Le due principali linee guida di riferimento sono:
#
# - **AAO-HNS**: *Clinical Consensus Statement: Recurrent Acute Otitis Externa* (Rosenfeld RM et al., *Otolaryngol Head Neck Surg*. 2020;162(2_suppl):S1-S40).
# - **NICE**: *Otitis externa* (NICE guideline NG98, 2018; ultimo aggiornamento 2023).
#
# Di seguito il confronto strutturato sui tre focus richiesti.
#
# ---
#
# ## 1. Protocolli di decolonizzazione per *S. aureus*
#
# | Aspetto | AAO-HNS (2020) | NICE (NG98) |
# |--------|----------------|-------------|
# | **Raccomandazione** | Suggerisce di **offrire** la decolonizzazione ai pazienti con otite esterna acuta recidivante (≥3 episodi in 6 mesi o ≥4 in 12 mesi) e infezione documentata da *S. aureus* (tampone colturale). Forza: suggerimento debole (statement 9). | Raccomanda di **considerare** un ciclo di unguento nasale antibiotico (es. mupirocina) se l’infezione è sostenuta da *S. aureus*, per eradicare lo stato di portatore nasale (raccomandazione 1.4.5). Forza: raccomandazione condizionale (“consider”). |
# | **Regime di decolonizzazione** | Mupirocina 2% unguento nasale **2 volte/die per 5–10 giorni** + **lavaggi cutanei con clorexidina 4%** (doccia/bagno) 1 volta/die per 5–10 giorni. Può essere considerato anche il trattamento dei contatti familiari in caso di recidive persistenti. | Mupirocina unguento nasale (non specifica posologia; nella pratica UK: 3 volte/die per 5 giorni). **Non menziona** l’uso di clorexidina per lavaggi cutanei nel contesto dell’otite esterna. |
# | **Evidenza e note** | Basata su studi osservazionali e analogia con linee guida per infezioni cutanee stafilococciche ricorrenti. La decolonizzazione combinata (naso + cute) è ritenuta più efficace della sola mupirocina nasale. | Si limita alla sola eradicazione del reservoir nasale, coerentemente con l’impostazione di *antimicrobial stewardship* del NICE. Non cita lavaggi con antisettici per la cute. |
#
# **Differenza chiave**: AAO-HNS propone un approccio più aggressivo e strutturato (decolonizzazione combinata naso-cute), mentre NICE si concentra esclusivamente sulla mupirocina nasale, senza includere la clorexidina cutanea.
#
# ---
#
# ## 2. Differenze nell’uso profilattico di antibiotici o acidificanti
#
# | Aspetto | AAO-HNS (2020) | NICE (NG98) |
# |--------|----------------|-------------|
# | **Antibiotici topici profilattici** | **Sconsigliati fortemente**: “I clinici non dovrebbero prescrivere antibiotici topici profilattici per l’otite esterna acuta recidivante” (statement 7, raccomandazione forte). Motivazione: rischio di resistenza, sensibilizzazione, alterazione del microbiota. | **Sconsigliati**: “Non offrire antibiotici topici per la prevenzione dell’otite esterna” (raccomandazione 1.4.6). Stessa forza e motivazione. |
# | **Acidificanti topici** | **Raccomandati**: “I clinici dovrebbero raccomandare l’acidificazione topica con acido acetico al 2% in gocce dopo esposizione all’acqua per prevenire le recidive” (statement 6, raccomandazione forte). | **Raccomandati**: “Consigliare alle persone con otite esterna ricorrente di usare gocce auricolari acidificanti dopo il nuoto, il bagno o la doccia, se sono soggette a infezioni ricorrenti” (raccomandazione 1.4.3). |
# | **Antibiotici sistemici profilattici** | Non affrontati specificamente per la profilassi; la terapia sistemica è riservata ai casi complicati o con estensione extrameatale. | Non menzionati per la profilassi. |
# | **Decolonizzazione come profilassi** | Vedi punto 1: suggerita in caso di infezione documentata da *S. aureus*. | Vedi punto 1: considerata come trial terapeutico per eradicare lo stato di portatore. |
#
# **Differenza chiave**: Sostanziale allineamento. Entrambe le linee guida vietano gli antibiotici topici profilattici e promuovono l’uso di acidificanti (acido acetico 2%) dopo esposizione all’acqua. L’unica profilassi farmacologica ammessa è la decolonizzazione stafilococcica, ma con le differenze descritte sopra.
#
# ---
#
# ## 3. Criteri per l’invio allo specialista o ulteriori indagini (es. screening diabete)
#
# | Aspetto | AAO-HNS (2020) | NICE (NG98) |
# |--------|----------------|-------------|
# | **Invio allo specialista ORL** | Suggerisce di **inviare** i pazienti con otite esterna acuta recidivante a un otorinolaringoiatra se: fallimento della gestione medica, complicanza (es. pericondrite, mastoidite), o condizione sottostante che richieda cure specialistiche (statement 11). | Raccomanda di **considerare l’invio** a uno specialista ORL se: otite esterna grave o ricorrente che non risponde al trattamento, oppure se è presente una condizione sottostante che necessita di gestione specialistica (come diabete o immunodepressione) (raccomandazione 1.5.2). |
# | **Screening per diabete mellito** | Suggerisce di **offrire lo screening per diabete** ai pazienti con otite esterna acuta recidivante che presentano fattori di rischio per diabete o che hanno infezioni gravi, refrattarie o ricorrenti (statement 10). Lo screening può essere eseguito con glicemia a digiuno o HbA1c. | **Non raccomanda esplicitamente** lo screening diabetologico di routine. Tuttavia, il diabete è citato come esempio di condizione sottostante che può richiedere l’invio specialistico. Nella pratica, il medico di base può decidere di eseguire un controllo glicemico in base al giudizio clinico. |
# | **Altre indagini** | Tampone colturale auricolare e nasale per identificare *S. aureus* e guidare la decolonizzazione. | Tampone microbiologico “da considerare” in caso di episodi ricorrenti per orientare la terapia (raccomandazione 1.4.4). |
#
# **Differenza chiave**: AAO-HNS è più esplicito e proattivo nel raccomandare lo screening per diabete nei pazienti con recidive, mentre NICE lascia la decisione al clinico, menzionando il diabete solo come possibile *driver* per l’invio specialistico. Entrambi concordano sull’invio in caso di mancata risposta o complicanze.
#
# ---
#
# ## Bibliografia essenziale
#
# 1. Rosenfeld RM, Schwartz SR, Cannon CR, et al. Clinical Consensus Statement: Recurrent Acute Otitis Externa. *Otolaryngol Head Neck Surg*. 2020;162(2_suppl):S1-S40. doi:10.1177/0194599820907279
# 2. National Institute for Health and Care Excellence. Otitis externa. NICE guideline [NG98]. Published March 2018, updated August 2023. Available at: https://www.nice.org.uk/guidance/ng98
#
# ---
#
# ## Abstract riassuntivo
#
# Le linee guida AAO-HNS e NICE convergono nel vietare la profilassi antibiotica topica e nel raccomandare l’uso di acidificanti (acido acetico 2%) dopo esposizione all’acqua per prevenire le recidive di furuncolosi del condotto uditivo. Entrambe riconoscono il ruolo della decolonizzazione stafilococcica, ma con approcci differenti: AAO-HNS suggerisce un regime combinato (mupirocina nasale + clorexidina cutanea) nei pazienti con infezione documentata da *S. aureus*, mentre NICE si limita a considerare la sola mupirocina nasale. Sul piano delle indagini, AAO-HNS propone attivamente lo screening per diabete nei soggetti con recidive e fattori di rischio, mentre NICE non formalizza tale raccomandazione, affidandosi al giudizio clinico. L’invio allo specialista ORL è indicato in caso di fallimento terapeutico, complicanze o condizioni predisponenti in entrambe le linee guida.
