# %% [markdown]
# <a href="https://colab.research.google.com/github/venezianof/booksum/blob/main/Copia_di_surveyxpynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚀 Guida Semplificata per SurveyX
#
# Benvenuto! Segui questi passaggi per generare la tua ricerca accademica:
#
# 1. **Setup Iniziale**: Esegui la prima cella per installare LaTeX e scaricare il codice.
# 2. **Configurazione API**: Inserisci le tue chiavi API (OpenAI o SiliconFlow) nella cella delle variabili.
# 3. **Parametri Ricerca**: Modifica il titolo e le parole chiave per il tuo argomento.
# 4. **Esecuzione**: Una volta impostato tutto, esegui le celle in ordine.
#
# *Nota: L'installazione di `texlive-full` può richiedere diversi minuti.*

# %% [markdown]
# # 🚀 Guida Semplificata per SurveyX
#
# Benvenuto! Segui questi passaggi per generare la tua ricerca accademica:
#
# 1. **Setup Iniziale**: Esegui la prima cella per installare LaTeX e scaricare il codice.
# 2. **Configurazione API**: Inserisci le tue chiavi API (OpenAI o SiliconFlow) nella cella delle variabili.
# 3. **Parametri Ricerca**: Modifica il titolo e le parole chiave per il tuo argomento.
# 4. **Esecuzione**: Una volta impostato tutto, esegui le celle in ordine.
#
# *Nota: L'installazione di `texlive-full` può richiedere diversi minuti.*

# %% [markdown]
# ## Resources
#
# ```bibtex
# @misc{liang2025surveyxacademicsurveyautomation,
#       title={SurveyX: Academic Survey Automation via Large Language Models},
#       author={Xun Liang and Jiawei Yang and Yezhaohui Wang and Chen Tang and Zifan Zheng and Shichao Song and Zehao Lin and Yebin Yang and Simin Niu and Hanyu Wang and Bo Tang and Feiyu Xiong and Keming Mao and Zhiyu li},
#       year={2025},
#       eprint={2502.14776},
#       archivePrefix={arXiv},
#       primaryClass={cs.CL},
#       url={https://arxiv.org/abs/2502.14776},
# }
# ```

# %%
import os

# !sudo apt update && sudo apt install texlive-full
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [91.2 kB]
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,915 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,294 kB]
# ...

# %%
# !git clone https://github.com/IAAR-Shanghai/SurveyX.git

# %%
import os
# Crea la cartella se non esiste ed entra
if not os.path.exists('SurveyX'):
    # !git clone https://github.com/IAAR-Shanghai/SurveyX.git

os.chdir('/content/SurveyX')
print(f"Ora ti trovi in: {os.getcwd()}")

# %%
os.chdir('SurveyX')
print(f"Current working directory changed to: {os.getcwd()}")

# %%
REMOTE_URL = "https://api.openai.com/v1/chat/completions"
TOKEN = "sk-xxxx..."
DEFAULT_EMBED_ONLINE_MODEL = "BAAI/bge-base-en-v1.5"
EMBED_REMOTE_URL = "https://api.siliconflow.cn/v1/embeddings"
EMBED_TOKEN = "your embed token here"

# %%
# Configurazione manuale dei parametri API
import os

# Inserisci qui i tuoi dati reali
API_TOKEN = "sk-xxxx..." # La tua chiave OpenAI o SiliconFlow
EMBED_TOKEN = "your_embed_token_here"

# Esempio di configurazione per il file config.py di SurveyX
# Se il progetto richiede un file specifico, possiamo scriverlo così:
config_content = f"""
REMOTE_URL = "https://api.openai.com/v1/chat/completions"
TOKEN = "{API_TOKEN}"
DEFAULT_EMBED_ONLINE_MODEL = "BAAI/bge-base-en-v1.5"
EMBED_REMOTE_URL = "https://api.siliconflow.cn/v1/embeddings"
EMBED_TOKEN = "{EMBED_TOKEN}"
"""

with open('config.py', 'w') as f:
    f.write(config_content)

print("File config.py creato con successo!")

# %%
import os

# Adjust these parameters as needed
SURVEY_TITLE = "Your Survey Title"
KEY_WORDS = "keyword1, keyword2, ..."
REF_PATH = "path/to/your/reference/dir"

# Note: This command assumes 'path/to/your/reference/dir' exists or is handled by SurveyX internally.
# If you don't have a specific reference directory, you might need to adjust or omit this argument based on SurveyX's requirements.
# !python tasks/offline_run.py --title "{SURVEY_TITLE}" --key_words "{KEY_WORDS}" --ref_path "{REF_PATH}"

# %%
# Set the task_id as an environment variable
os.environ['task_id'] = "your_task_id"
print(f"Environment variable TASK_ID set to: {os.environ.get('task_id')}")

# %%
# Execute workflow step 03: Generate outlines
# !python tasks/workflow/03_gen_outlines.py --task_id $task_id

# %%
# Execute workflow step 04: Generate content
# !python tasks/workflow/04_gen_content.py --task_id $task_id

# %%
# Execute workflow step 05: Post-refine
# !python tasks/workflow/05_post_refine.py --task_id $task_id

# %%
# Execute workflow step 06: Generate LaTeX
# !python tasks/workflow/06_gen_latex.py --task_id $task_id

# %% [markdown]
# ### 💾 Stato del Lavoro
#
# - **Configurazione**: Completata (file `config.py` creato).
# - **Cartella**: `/content/SurveyX`.
# - **Prossimo Passo**: Inserire il titolo della ricerca nella cella `a7327f3f` ed eseguirla al rientro.
#
# *Ricorda di salvare il file `.ipynb` tramite il menu File di Colab.*
